# %%
#supress warnings
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import sys
import os
_stderr = sys.stderr
null = open(os.devnull,'wb')

import scanpy as sc
#set some figure parameters for nice display inside jupyternotebooks.
# %matplotlib inline
sc.settings.set_figure_params(dpi=80, frameon=False, figsize=(5, 5), facecolor='white')

# %% [markdown]
# ## Prep our RNA adata structure

# %%
adata = sc.read_10x_h5("/rugpfs/fs0/tavz_lab/scratch/amillet/11_16_2022_Alon/E4AD_1yr-ATAC/outs/filtered_feature_bc_matrix.h5")
adata.var_names_make_unique()
adata

# %%
import pandas as pd
import numpy as np
cell_annot = pd.read_csv('/ru-auth/local/home/amillet/Multivelo/E4AD_1yr/Mglia_Only/annots.csv', sep=',', index_col=0)

# %%
adata = adata[np.isin(adata.obs.index,cell_annot.index)]

# %%
adata = adata[cell_annot.index,:]
adata.obs['celltype'] = cell_annot['mglia_ident']

# %%
sc.pp.filter_genes(adata, min_cells=3)

# %%
adata.raw = adata
sc.pp.normalize_total(adata, target_sum=1e4)
sc.pp.log1p(adata)
sc.pp.highly_variable_genes(adata, min_mean=0.0125, max_mean=3, min_disp=0.5)
adata = adata[:, adata.var.highly_variable]
sc.pp.scale(adata, max_value=10)

# %%
sc.pp.neighbors(adata, n_neighbors=10, n_pcs=10)
sc.tl.umap(adata)
sc.pl.umap(adata, color = 'celltype')

# %%
adata.write(('E4AD_1yr/rna_adata.h5ad'), compression='gzip')

# %% [markdown]
# ## Prep our ATAC adata structure

# %%
import os
import pycisTopic
#set some figure parameters for nice display inside jupyternotebooks.
# %matplotlib inline

# %%
import scanpy as sc
adata = sc.read_h5ad('E4AD_1yr/rna_adata.h5ad')
cell_data = adata.obs
cell_data['sample_id'] = 'E4AD_1yr'
cell_data['celltype'] = cell_data['celltype'].astype(str) # set data type of the celltype column to str, otherwise the export_pseudobulk function will complain.
del(adata)

# %%
# Get chromosome sizes (for mm10 here)
import pyranges as pr
import requests
import pandas as pd
target_url='https://hgdownload.cse.ucsc.edu/goldenPath/mm10/bigZips/mm10.chrom.sizes'
chromsizes=pd.read_csv(target_url, sep='\t', header=None)
chromsizes.columns=['Chromosome', 'End']
chromsizes['Start']=[0]*chromsizes.shape[0]
chromsizes=chromsizes.loc[:,['Chromosome', 'Start', 'End']]
# Exceptionally in this case, to agree with CellRangerARC annotations
chromsizes['Chromosome'] = [chromsizes['Chromosome'][x].replace('v', '.') for x in range(len(chromsizes['Chromosome']))]
chromsizes['Chromosome'] = [chromsizes['Chromosome'][x].split('_')[1] if len(chromsizes['Chromosome'][x].split('_')) > 1 else chromsizes['Chromosome'][x] for x in range(len(chromsizes['Chromosome']))]
chromsizes=pr.PyRanges(chromsizes)

# %%
# there are some rando chromosomes in the fragments file that are not present in chromsizes. to filter them,
# i write chromsizes to a csv and will use this in R to quickly do filtering of the fragments tsv
chromsizes.to_csv("mm10_chromsizes.csv")

# %%
# processing being done in scenicplus/E4AD_1yr/frag_filtering.R
# the new, filtered fragments file is being saved as scenicplus/E4AD_1yr/atac_fragments_filtered.tsv.gz
fragments_dict = {'E4AD_1yr': '/lustre/fs4/home/amillet/scenicplus/E4AD_1yr/atac_fragments_filtered.tsv.gz'}

# %%
from pycisTopic.pseudobulk_peak_calling import export_pseudobulk
bw_paths, bed_paths = export_pseudobulk(input_data = cell_data,
                 variable = 'celltype',                                                                     # variable by which to generate pseubulk profiles, in this case we want pseudobulks per celltype
                 sample_id_col = 'sample_id',
                 chromsizes = chromsizes,
                 bed_path = '/lustre/fs4/home/amillet/scenicplus/E4AD_1yr/consensus_peak_calling/pseudobulk_bed_files/',  # specify where pseudobulk_bed_files should be stored
                 bigwig_path = '/lustre/fs4/home/amillet/scenicplus/E4AD_1yr/consensus_peak_calling/pseudobulk_bw_files/',# specify where pseudobulk_bw_files should be stored
                 path_to_fragments = fragments_dict,                                                        # location of fragment fiels
                 n_cpu = 8,                                                                                 # specify the number of cores to use, we use ray for multi processing
                 normalize_bigwig = True,
                 remove_duplicates = True,
                 _temp_dir = "/lustre/fs4/home/amillet/ray_spill",      
                 split_pattern = '-')

# %%
import pickle
pickle.dump(bed_paths,
            open('E4AD_1yr/consensus_peak_calling/pseudobulk_bed_files/bed_paths.pkl', 'wb'))
pickle.dump(bw_paths,
           open('E4AD_1yr/consensus_peak_calling/pseudobulk_bed_files/bw_paths.pkl', 'wb'))

# %%
bed_paths

# %%
import pickle
bed_paths = pickle.load(open('E4AD_1yr/consensus_peak_calling/pseudobulk_bed_files/bed_paths.pkl', 'rb'))
bw_paths =  pickle.load(open('E4AD_1yr/consensus_peak_calling/pseudobulk_bed_files/bw_paths.pkl', 'rb'))
from pycisTopic.pseudobulk_peak_calling import peak_calling
macs_path='macs2'
# Run peak calling
narrow_peaks_dict = peak_calling(macs_path,
                                 bed_paths,
                                 'E4AD_1yr/consensus_peak_calling/MACS/',
                                 genome_size='mm',
                                 n_cpu=8,
                                 input_format='BEDPE',
                                 shift=73,
                                 ext_size=146,
                                 keep_dup = 'all',
                                 q_value = 0.05,
                                 _temp_dir = "/lustre/fs4/home/amillet/ray_spill")

# %%
# ray has some weird rules about the temp_dir name length.
# had to choose a folder close to home for actual run,
# transferring to scenicplus/E4AD_1yr folder after the fact.
import shutil
shutil.move("/lustre/fs4/home/amillet/ray_spill", "/lustre/fs4/home/amillet/scenicplus/E4AD_1yr")

# %%
pickle.dump(narrow_peaks_dict,
            open('E4AD_1yr/consensus_peak_calling/MACS/narrow_peaks_dict.pkl', 'wb'))

# %%
from pycisTopic.iterative_peak_calling import *
# Other param
peak_half_width = 250
path_to_blacklist= 'mm10-blacklist.v2.bed' #downloaded from aertslab github
# Get consensus peaks
consensus_peaks=get_consensus_peaks(narrow_peaks_dict, peak_half_width, chromsizes=chromsizes, path_to_blacklist=path_to_blacklist)

# %%
consensus_peaks.to_bed(
    path = 'E4AD_1yr/consensus_peak_calling/consensus_regions.bed',
    keep=True,
    compression='infer',
    chain=False)

# %% [markdown]
# ### QC

# %%
import pybiomart as pbm
dataset = pbm.Dataset(name='mmusculus_gene_ensembl',  host='http://www.ensembl.org')
annot = dataset.query(attributes=['chromosome_name', 'transcription_start_site', 'strand', 'external_gene_name', 'transcript_biotype'])
annot['Chromosome/scaffold name'] = annot['Chromosome/scaffold name'].to_numpy(dtype = str)
filter = annot['Chromosome/scaffold name'].str.contains('CHR|GL|JH|MT')
annot = annot[~filter]
annot['Chromosome/scaffold name'] = annot['Chromosome/scaffold name'].str.replace(r'(\b\S)', r'chr\1')
annot.columns=['Chromosome', 'Start', 'Strand', 'Gene', 'Transcript_type']
annot = annot[annot.Transcript_type == 'protein_coding']
from pycisTopic.qc import *
path_to_regions = {'E4AD_1yr':'E4AD_1yr/consensus_peak_calling/consensus_regions.bed'}

metadata_bc, profile_data_dict = compute_qc_stats(
                fragments_dict = fragments_dict,
                tss_annotation = annot,
                stats=['barcode_rank_plot', 'duplicate_rate', 'insert_size_distribution', 'profile_tss', 'frip'],
                label_list = None,
                path_to_regions = path_to_regions,
                n_cpu = 1,
                valid_bc = None,
                n_frag = 100,
                n_bc = None,
                tss_flank_window = 1000,
                tss_window = 50,
                tss_minimum_signal_window = 100,
                tss_rolling_window = 10,
                remove_duplicates = True,
                _temp_dir = "/lustre/fs4/home/amillet/ray_spill")

if not os.path.exists('E4AD_1yr/quality_control'):
    os.makedirs('E4AD_1yr/quality_control')

pickle.dump(metadata_bc,
            open('E4AD_1yr/quality_control/metadata_bc.pkl', 'wb'))

pickle.dump(profile_data_dict,
            open('E4AD_1yr/quality_control/profile_data_dict.pkl', 'wb'))

# %%
                        #[min,  #max]
QC_filters = {
    'Log_unique_nr_frag': [3.3 , None],
    'FRIP':               [0.4, None],
    'TSS_enrichment':     [1   , None],
    'Dupl_rate':          [None, None]

}

# Return figure to plot together with other metrics, and cells passing filters. Figure will be saved as pdf.
from pycisTopic.qc import *
FRIP_NR_FRAG_fig, FRIP_NR_FRAG_filter=plot_barcode_metrics(metadata_bc['E4AD_1yr'],
                                       var_x='Log_unique_nr_frag',
                                       var_y='FRIP',
                                       min_x=QC_filters['Log_unique_nr_frag'][0],
                                       max_x=QC_filters['Log_unique_nr_frag'][1],
                                       min_y=QC_filters['FRIP'][0],
                                       max_y=QC_filters['FRIP'][1],
                                       return_cells=True,
                                       return_fig=True,
                                       plot=False)
# Return figure to plot together with other metrics, and cells passing filters
TSS_NR_FRAG_fig, TSS_NR_FRAG_filter=plot_barcode_metrics(metadata_bc['E4AD_1yr'],
                                      var_x='Log_unique_nr_frag',
                                      var_y='TSS_enrichment',
                                      min_x=QC_filters['Log_unique_nr_frag'][0],
                                      max_x=QC_filters['Log_unique_nr_frag'][1],
                                      min_y=QC_filters['TSS_enrichment'][0],
                                      max_y=QC_filters['TSS_enrichment'][1],
                                      return_cells=True,
                                      return_fig=True,
                                      plot=False)
# Return figure to plot together with other metrics, but not returning cells (no filter applied for the duplication rate  per barcode)
DR_NR_FRAG_fig=plot_barcode_metrics(metadata_bc['E4AD_1yr'],
                                      var_x='Log_unique_nr_frag',
                                      var_y='Dupl_rate',
                                      min_x=QC_filters['Log_unique_nr_frag'][0],
                                      max_x=QC_filters['Log_unique_nr_frag'][1],
                                      min_y=QC_filters['Dupl_rate'][0],
                                      max_y=QC_filters['Dupl_rate'][1],
                                      return_cells=False,
                                      return_fig=True,
                                      plot=False,
                                      plot_as_hexbin = True)

# Plot barcode stats in one figure
fig=plt.figure(figsize=(10,10))
plt.subplot(1, 3, 1)
img = fig2img(FRIP_NR_FRAG_fig)
plt.imshow(img)
plt.axis('off')
plt.subplot(1, 3, 2)
img = fig2img(TSS_NR_FRAG_fig)
plt.imshow(img)
plt.axis('off')
plt.subplot(1, 3, 3)
img = fig2img(DR_NR_FRAG_fig)
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
bc_passing_filters = {'E4AD_1yr':[]}
bc_passing_filters['E4AD_1yr'] = list((set(FRIP_NR_FRAG_filter) & set(TSS_NR_FRAG_filter)))
pickle.dump(bc_passing_filters,
            open('E4AD_1yr/quality_control/bc_passing_filters.pkl', 'wb'))
print(f"{len(bc_passing_filters['E4AD_1yr'])} barcodes passed QC stats")

# %% [markdown]
# ### Topic Modeling

# %%
import scanpy as sc
adata = sc.read_h5ad('E4AD_1yr/rna_adata.h5ad')
scRNA_bc = adata.obs_names
cell_data = adata.obs
cell_data['sample_id'] = 'E4AD_1yr'
cell_data['celltype'] = cell_data['celltype'].astype(str) # set data type of the celltype column to str, otherwise the export_pseudobulk function will complain.
del(adata)

# %%
import pickle
fragments_dict = {'E4AD_1yr': '/lustre/fs4/home/amillet/scenicplus/E4AD_1yr/atac_fragments_filtered.tsv.gz'}
path_to_regions = {'E4AD_1yr': 'E4AD_1yr/consensus_peak_calling/consensus_regions.bed'}
path_to_blacklist= 'mm10-blacklist.v2.bed'
metadata_bc = pickle.load(open('E4AD_1yr/quality_control/metadata_bc.pkl', 'rb'))
bc_passing_filters = pickle.load(open('E4AD_1yr/quality_control/bc_passing_filters.pkl', 'rb'))

# %%
print(f"{len(list(set(bc_passing_filters['E4AD_1yr']) & set(scRNA_bc)))} cell barcodes pass both scATAC-seq and scRNA-seq based filtering")

# %%
from pycisTopic.cistopic_class import *
key = 'E4AD_1yr'
cistopic_obj = create_cistopic_object_from_fragments(
                            path_to_fragments=fragments_dict[key],
                            path_to_regions=path_to_regions[key],
                            path_to_blacklist=path_to_blacklist,
                            metrics=metadata_bc[key],
                            valid_bc=list(set(scRNA_bc)), # removing `set(bc_passing_filters[key]) & ` as RNA is already prefiltered on both 
                            n_cpu=1,
                            project=key,
                            split_pattern='-')
cistopic_obj.add_cell_data(cell_data, split_pattern='-')
print(cistopic_obj)

# %%
pickle.dump(cistopic_obj,
            open('E4AD_1yr/cistopic_obj.pkl', 'wb'))

# %%
# import pickle
cistopic_obj = pickle.load(open('E4AD_1yr/cistopic_obj.pkl', 'rb'))
from pycisTopic.cistopic_class import *
models=run_cgs_models(cistopic_obj,
                    n_topics=[2,4,10,16,32,48],
                    n_cpu=5,
                    n_iter=500,
                    random_state=555,
                    alpha=50,
                    alpha_by_topic=True,
                    eta=0.1,
                    eta_by_topic=False,
                    save_path=None,
                    _temp_dir = "/lustre/fs4/home/amillet/ray_spill")

# %%
if not os.path.exists('E4AD_1yr/models'):
    os.makedirs('E4AD_1yr/models')

pickle.dump(models,
            open('E4AD_1yr/models/10x_pbmc_models_500_iter_LDA.pkl', 'wb'))

# %%
models = pickle.load(open('E4AD_1yr/models/10x_pbmc_models_500_iter_LDA.pkl', 'rb'))
cistopic_obj = pickle.load(open('E4AD_1yr/cistopic_obj.pkl', 'rb'))
from pycisTopic.lda_models import *
model = evaluate_models(models,
                       select_model=32,
                       return_model=True,
                       metrics=['Arun_2010','Cao_Juan_2009', 'Minmo_2011', 'loglikelihood'],
                       plot_metrics=False)

# %%
cistopic_obj.add_LDA_model(model)
pickle.dump(cistopic_obj,
            open('E4AD_1yr/cistopic_obj.pkl', 'wb'))

# %%
from pycisTopic.clust_vis import *
run_umap(cistopic_obj, target  = 'cell', scale=True)
plot_metadata(cistopic_obj, reduction_name = 'UMAP', variables = ['celltype'])

# %%
plot_topic(cistopic_obj, reduction_name = 'UMAP', num_columns = 4)

# %%
from pycisTopic.topic_binarization import *
region_bin_topics_otsu = binarize_topics(cistopic_obj, method='otsu')
region_bin_topics_top3k = binarize_topics(cistopic_obj, method='ntop', ntop = 3000)

# %%
import numpy as np
from pycisTopic.diff_features import *
imputed_acc_obj = impute_accessibility(cistopic_obj, selected_cells=None, selected_regions=None, scale_factor=10**6)
normalized_imputed_acc_obj = normalize_scores(imputed_acc_obj, scale_factor=10**4)
variable_regions = find_highly_variable_features(normalized_imputed_acc_obj, plot = False)
markers_dict = find_diff_features(cistopic_obj, imputed_acc_obj, variable='celltype', 
                                  var_features=variable_regions, split_pattern = '-',
                                 adjpval_thr = 0.1, log2fc_thr = np.log2(1.1))

# %%
if not os.path.exists('E4AD_1yr/candidate_enhancers'):
    os.makedirs('E4AD_1yr/candidate_enhancers')
import pickle
pickle.dump(region_bin_topics_otsu, open('E4AD_1yr/candidate_enhancers/region_bin_topics_otsu.pkl', 'wb'))
pickle.dump(region_bin_topics_top3k, open('E4AD_1yr/candidate_enhancers/region_bin_topics_top3k.pkl', 'wb'))
pickle.dump(markers_dict, open('E4AD_1yr/candidate_enhancers/markers_dict.pkl', 'wb'))

# %% [markdown]
# ## PyCisTarget Motif Enrichment Analysis

# %%
import pickle
region_bin_topics_otsu = pickle.load(open('E4AD_1yr/candidate_enhancers/region_bin_topics_otsu.pkl', 'rb'))
region_bin_topics_top3k = pickle.load(open('E4AD_1yr/candidate_enhancers/region_bin_topics_top3k.pkl', 'rb'))
markers_dict = pickle.load(open('E4AD_1yr/candidate_enhancers/markers_dict.pkl', 'rb'))

# %%
import pyranges as pr
from pycistarget.utils import region_names_to_coordinates
region_sets = {}
region_sets['topics_otsu'] = {}
region_sets['topics_top_3'] = {}
region_sets['DARs'] = {}
for topic in region_bin_topics_otsu.keys():
    regions = region_bin_topics_otsu[topic].index[region_bin_topics_otsu[topic].index.str.startswith('chr')] #only keep regions on known chromosomes
    region_sets['topics_otsu'][topic] = pr.PyRanges(region_names_to_coordinates(regions))
for topic in region_bin_topics_top3k.keys():
    regions = region_bin_topics_top3k[topic].index[region_bin_topics_top3k[topic].index.str.startswith('chr')] #only keep regions on known chromosomes
    region_sets['topics_top_3'][topic] = pr.PyRanges(region_names_to_coordinates(regions))
for DAR in markers_dict.keys():
    regions = markers_dict[DAR].index[markers_dict[DAR].index.str.startswith('chr')] #only keep regions on known chromosomes
    region_sets['DARs'][DAR] = pr.PyRanges(region_names_to_coordinates(regions))

# %%
for key in region_sets.keys():
    print(f'{key}: {region_sets[key].keys()}')

# %%
rankings_db = '/ru-auth/local/home/amillet/scratch/references/cistarget/mm10_screen_v10_clust.regions_vs_motifs.rankings.feather'
scores_db = '/ru-auth/local/home/amillet/scratch/references/cistarget/mm10_screen_v10_clust.regions_vs_motifs.scores.feather'
motif_annotation = '/ru-auth/local/home/amillet/scratch/references/cistarget/motifs-v10nr_clust-nr.mgi-m0.001-o0.0.tbl'

# %%
if not os.path.exists('E4AD_1yr/motifs'):
    os.makedirs('E4AD_1yr/motifs')
from scenicplus.wrappers.run_pycistarget import run_pycistarget
run_pycistarget(
    region_sets = region_sets,
    species = 'mus_musculus',
    save_path = 'E4AD_1yr/motifs',
    ctx_db_path = rankings_db,
    dem_db_path = scores_db,
    path_to_motif_annotations = motif_annotation,
    run_without_promoters = True,
    n_cpu = 8,
    _temp_dir = "/lustre/fs4/home/amillet/ray_spill",
    annotation_version = 'v10nr_clust',
    )

# %%
import dill
menr = dill.load(open('E4AD_1yr/motifs/menr.pkl', 'rb'))

# %%
menr['DEM_topics_otsu_All'].DEM_results('Topic17')

# %% [markdown]
# # Finally!! Time to run SCENIC+.

# %%
import dill
import scanpy as sc
import os
import warnings
warnings.filterwarnings("ignore")
import pandas
import pyranges
# Set stderr to null to avoid strange messages from ray
import sys
_stderr = sys.stderr
null = open(os.devnull,'wb')

adata = sc.read_h5ad('E4AD_1yr/rna_adata.h5ad')
cistopic_obj = dill.load(open('E4AD_1yr/cistopic_obj.pkl', 'rb'))
menr = dill.load(open('E4AD_1yr/motifs/menr.pkl', 'rb'))

# %%
from scenicplus.scenicplus_class import create_SCENICPLUS_object
import numpy as np
scplus_obj = create_SCENICPLUS_object(
    GEX_anndata = adata.raw.to_adata(),
    cisTopic_obj = cistopic_obj,
    menr = menr,
    bc_transform_func = lambda x: f'{x}-E4AD_1yr' #function to convert scATAC-seq barcodes to scRNA-seq ones
)
scplus_obj.X_EXP = np.array(scplus_obj.X_EXP.todense())
scplus_obj

# %% [markdown]
# Check which biomart host is best:

# %%
ensembl_version_dict = {'105': 'http://www.ensembl.org',
                        '104': 'http://may2021.archive.ensembl.org/',
                        '103': 'http://feb2021.archive.ensembl.org/',
                        '102': 'http://nov2020.archive.ensembl.org/',
                        '101': 'http://aug2020.archive.ensembl.org/',
                        '100': 'http://apr2020.archive.ensembl.org/',
                        '99': 'http://jan2020.archive.ensembl.org/',
                        '98': 'http://sep2019.archive.ensembl.org/',
                        '97': 'http://jul2019.archive.ensembl.org/',
                        '96': 'http://apr2019.archive.ensembl.org/',
                        '95': 'http://jan2019.archive.ensembl.org/',
                        '94': 'http://oct2018.archive.ensembl.org/',
                        '93': 'http://jul2018.archive.ensembl.org/',
                        '92': 'http://apr2018.archive.ensembl.org/',
                        '91': 'http://dec2017.archive.ensembl.org/',
                        '90': 'http://aug2017.archive.ensembl.org/',
                        '89': 'http://may2017.archive.ensembl.org/',
                        '88': 'http://mar2017.archive.ensembl.org/',
                        '87': 'http://dec2016.archive.ensembl.org/',
                        '86': 'http://oct2016.archive.ensembl.org/',
                        '80': 'http://may2015.archive.ensembl.org/',
                        '77': 'http://oct2014.archive.ensembl.org/',
                        '75': 'http://feb2014.archive.ensembl.org/',
                        '54': 'http://may2009.archive.ensembl.org/'}

import pybiomart as pbm
def test_ensembl_host(scplus_obj, host, species):
    dataset = pbm.Dataset(name=species+'_gene_ensembl',  host=host)
    annot = dataset.query(attributes=['chromosome_name', 'transcription_start_site', 'strand', 'external_gene_name', 'transcript_biotype'])
    annot.columns = ['Chromosome', 'Start', 'Strand', 'Gene', 'Transcript_type']
    annot['Chromosome'] = annot['Chromosome'].astype('str')
    filter = annot['Chromosome'].str.contains('CHR|GL|JH|MT')
    annot = annot[~filter]
    annot.columns=['Chromosome', 'Start', 'Strand', 'Gene', 'Transcript_type']
    gene_names_release = set(annot['Gene'].tolist())
    ov=len([x for x in scplus_obj.gene_names if x in gene_names_release])
    print('Genes recovered: ' + str(ov) + ' out of ' + str(len(scplus_obj.gene_names)))
    return ov

n_overlap = {}
for version in ensembl_version_dict.keys():
    print(f'host: {version}')
    try:
        n_overlap[version] =  test_ensembl_host(scplus_obj, ensembl_version_dict[version], 'mmusculus')
    except:
        print('Host not reachable')
v = sorted(n_overlap.items(), key=lambda item: item[1], reverse=True)[0][0]
print(f"version: {v} has the largest overlap, use {ensembl_version_dict[v]} as biomart host")

# %%
biomart_host = "http://sep2019.archive.ensembl.org/"

# %% [markdown]
# We prep a list of all known mouse TFs, first by downloading the annotated txt file from http://bioinfo.life.hust.edu.cn/AnimalTFDB4/#/Download for mouse and saving it to `scenicplus/Mus_musculus_TF.txt`. Then we filter to just the TF names and save as a new txt file for use.

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("Mus_musculus_TF.txt", sep = "\t")
df = df['Symbol']
np.savetxt(r'Mus_musculus_TF_readytouse.txt', df.values, fmt='%s')

# %%
scplus_obj.dr_cell['GEX_X_pca'] = scplus_obj.dr_cell['GEX_X_pca'].iloc[:, 0:2]

# %%
from scenicplus.wrappers.run_scenicplus import run_scenicplus
try:
    run_scenicplus(
        scplus_obj = scplus_obj,
        variable = ['GEX_celltype'],
        species = 'mmusculus',
        assembly = 'mm10',
        tf_file = 'Mus_musculus_TF_readytouse.txt',
        save_path = 'E4AD_1yr/scenicplus',
        biomart_host = biomart_host,
        upstream = [1000, 150000],
        downstream = [1000, 150000],
        calculate_TF_eGRN_correlation = True,
        calculate_DEGs_DARs = True,
        export_to_loom_file = True,
        export_to_UCSC_file = True,
        path_bedToBigBed = '/ru-auth/local/home/amillet/scenicplus',
        n_cpu = 12,
        _temp_dir = "/lustre/fs4/home/amillet/ray_spill")
except Exception as e:
    #in case of failure, still save the object
    dill.dump(scplus_obj, open('E4AD_1yr/scenicplus/scplus_obj.pkl', 'wb'), protocol=-1)
    raise(e)
# Out:
# Processing: Top 15 region-to-gene links per gene, negative r2g:  91%|█████████ | 1206/1326 [00:39<00:02, 41.33it/s]
# Processing: Top 15 region-to-gene links per gene, negative r2g:  91%|█████████▏| 1213/1326 [00:39<00:02, 47.14it/s]
# Processing: Top 15 region-to-gene links per gene, negative r2g:  92%|█████████▏| 1219/1326 [00:39<00:02, 50.29it/s]
# Processing: Top 15 region-to-gene links per gene, negative r2g:  93%|█████████▎| 1227/1326 [00:39<00:01, 57.33it/s]
# Processing: Top 15 region-to-gene links per gene, negative r2g:  93%|█████████▎| 1233/1326 [00:40<00:01, 58.02it/s]
# Processing: Top 15 region-to-gene links per gene, negative r2g:  94%|█████████▎| 1240/1326 [00:40<00:01, 57.79it/s]
# Processing: Top 15 region-to-gene links per gene, negative r2g:  94%|█████████▍| 1247/1326 [00:40<00:01, 59.36it/s]
# Processing: Top 15 region-to-gene links per gene, negative r2g:  94%|█████████▍| 1253/1326 [00:40<00:01, 55.04it/s]
# Processing: Top 15 region-to-gene links per gene, negative r2g:  95%|█████████▍| 1259/1326 [00:40<00:01, 53.60it/s]
# Processing: Top 15 region-to-gene links per gene, negative r2g:  95%|█████████▌| 1266/1326 [00:40<00:01, 52.42it/s]
# Processing: Top 15 region-to-gene links per gene, negative r2g:  96%|█████████▌| 1272/1326 [00:40<00:01, 49.83it/s]
# Processing: Top 15 region-to-gene links per gene, negative r2g:  96%|█████████▋| 1278/1326 [00:40<00:01, 41.54it/s]
# Processing: Top 15 region-to-gene links per gene, negative r2g:  97%|█████████▋| 1283/1326 [00:41<00:01, 34.74it/s]
# Processing: Top 15 region-to-gene links per gene, negative r2g:  97%|█████████▋| 1287/1326 [00:41<00:01, 31.69it/s]
# Processing: Top 15 region-to-gene links per gene, negative r2g:  97%|█████████▋| 1291/1326 [00:41<00:01, 32.70it/s]
# Processing: Top 15 region-to-gene links per gene, negative r2g:  98%|█████████▊| 1295/1326 [00:41<00:00, 33.86it/s]
# Processing: Top 15 region-to-gene links per gene, negative r2g:  98%|█████████▊| 1299/1326 [00:41<00:00, 30.83it/s]
# Processing: Top 15 region-to-gene links per gene, negative r2g:  98%|█████████▊| 1303/1326 [00:41<00:00, 31.79it/s]
# Processing: Top 15 region-to-gene links per gene, negative r2g:  99%|█████████▊| 1307/1326 [00:42<00:00, 30.20it/s]
# Processing: Top 15 region-to-gene links per gene, negative r2g:  99%|█████████▉| 1312/1326 [00:42<00:00, 32.83it/s]
# Processing: Top 15 region-to-gene links per gene, negative r2g:  99%|█████████▉| 1317/1326 [00:42<00:00, 34.39it/s]
# Processing: Top 15 region-to-gene links per gene, negative r2g: 100%|█████████▉| 1321/1326 [00:42<00:00, 31.46it/s]
# Processing: Top 15 region-to-gene links per gene, negative r2g: 100%|█████████▉| 1325/1326 [00:42<00:00, 29.32it/s]
#  43%|████▎     | 6/14 [03:27<05:03, 37.90s/it]
# Processing: BASC binarized, negative r2g:   0%|          | 0/1326 [00:00<?, ?it/s]
# Processing: BASC binarized, negative r2g:   1%|          | 9/1326 [00:00<00:14, 89.65it/s]
# Processing: BASC binarized, negative r2g:   1%|▏         | 18/1326 [00:00<00:30, 42.79it/s]
# Processing: BASC binarized, negative r2g:   2%|▏         | 24/1326 [00:00<00:31, 41.19it/s]
# Processing: BASC binarized, negative r2g:   2%|▏         | 29/1326 [00:00<00:31, 40.77it/s]
# Processing: BASC binarized, negative r2g:   3%|▎         | 34/1326 [00:00<00:31, 41.30it/s]
# Processing: BASC binarized, negative r2g:   3%|▎         | 39/1326 [00:00<00:32, 40.06it/s]
# Processing: BASC binarized, negative r2g:   3%|▎         | 44/1326 [00:01<00:33, 38.52it/s]
# Processing: BASC binarized, negative r2g:   4%|▎         | 48/1326 [00:01<00:37, 33.95it/s]
# Processing: BASC binarized, negative r2g:   4%|▍         | 52/1326 [00:01<00:38, 32.77it/s]
# Processing: BASC binarized, negative r2g:   4%|▍         | 56/1326 [00:01<00:39, 32.25it/s]
# Processing: BASC binarized, negative r2g:   5%|▍         | 60/1326 [00:01<00:38, 32.62it/s]
# Processing: BASC binarized, negative r2g:   5%|▍         | 66/1326 [00:01<00:33, 37.42it/s]
# Processing: BASC binarized, negative r2g:   5%|▌         | 70/1326 [00:02<00:52, 23.73it/s]
# Processing: BASC binarized, negative r2g:   6%|▌         | 74/1326 [00:02<00:48, 25.57it/s]
# Processing: BASC binarized, negative r2g:   6%|▌         | 78/1326 [00:02<00:51, 24.39it/s]
# Processing: BASC binarized, negative r2g:   6%|▌         | 81/1326 [00:02<01:06, 18.77it/s]
# Processing: BASC binarized, negative r2g:   6%|▋         | 84/1326 [00:02<01:15, 16.36it/s]
# Processing: BASC binarized, negative r2g:   6%|▋         | 86/1326 [00:03<01:22, 14.96it/s]
# Processing: BASC binarized, negative r2g:   7%|▋         | 88/1326 [00:03<01:22, 15.06it/s]
# Processing: BASC binarized, negative r2g:   7%|▋         | 91/1326 [00:03<01:13, 16.86it/s]
# Processing: BASC binarized, negative r2g:   7%|▋         | 93/1326 [00:03<01:13, 16.73it/s]
# Processing: BASC binarized, negative r2g:   7%|▋         | 95/1326 [00:03<01:16, 16.02it/s]
# Processing: BASC binarized, negative r2g:   7%|▋         | 97/1326 [00:03<01:20, 15.27it/s]
# Processing: BASC binarized, negative r2g:   7%|▋         | 99/1326 [00:03<01:23, 14.76it/s]
# Processing: BASC binarized, negative r2g:   8%|▊         | 102/1326 [00:04<01:16, 15.99it/s]
# Processing: BASC binarized, negative r2g:   8%|▊         | 104/1326 [00:04<01:17, 15.78it/s]
# Processing: BASC binarized, negative r2g:   8%|▊         | 108/1326 [00:04<00:59, 20.58it/s]
# Processing: BASC binarized, negative r2g:   8%|▊         | 111/1326 [00:04<00:54, 22.39it/s]
# Processing: BASC binarized, negative r2g:   9%|▊         | 114/1326 [00:04<01:00, 20.10it/s]
# Processing: BASC binarized, negative r2g:   9%|▉         | 119/1326 [00:04<00:44, 26.86it/s]
# Processing: BASC binarized, negative r2g:  10%|▉         | 126/1326 [00:04<00:32, 37.17it/s]
# Processing: BASC binarized, negative r2g:  10%|█         | 134/1326 [00:04<00:25, 47.26it/s]
# Processing: BASC binarized, negative r2g:  11%|█         | 141/1326 [00:05<00:22, 52.04it/s]
# Processing: BASC binarized, negative r2g:  11%|█         | 149/1326 [00:05<00:20, 58.55it/s]
# Processing: BASC binarized, negative r2g:  12%|█▏        | 157/1326 [00:05<00:18, 63.83it/s]
# Processing: BASC binarized, negative r2g:  12%|█▏        | 165/1326 [00:05<00:17, 65.70it/s]
# Processing: BASC binarized, negative r2g:  13%|█▎        | 172/1326 [00:05<00:20, 55.51it/s]
# Processing: BASC binarized, negative r2g:  13%|█▎        | 178/1326 [00:05<00:30, 38.22it/s]
# Processing: BASC binarized, negative r2g:  14%|█▍        | 183/1326 [00:05<00:31, 35.76it/s]
# Processing: BASC binarized, negative r2g:  14%|█▍        | 188/1326 [00:06<00:30, 37.20it/s]
# Processing: BASC binarized, negative r2g:  15%|█▍        | 193/1326 [00:06<00:32, 35.32it/s]
# Processing: BASC binarized, negative r2g:  15%|█▍        | 198/1326 [00:06<00:30, 37.48it/s]
# Processing: BASC binarized, negative r2g:  15%|█▌        | 204/1326 [00:06<00:26, 42.43it/s]
# Processing: BASC binarized, negative r2g:  16%|█▌        | 213/1326 [00:06<00:21, 51.42it/s]
# Processing: BASC binarized, negative r2g:  17%|█▋        | 221/1326 [00:06<00:19, 58.06it/s]
# Processing: BASC binarized, negative r2g:  17%|█▋        | 231/1326 [00:06<00:16, 67.77it/s]
# Processing: BASC binarized, negative r2g:  18%|█▊        | 241/1326 [00:06<00:14, 75.73it/s]
# Processing: BASC binarized, negative r2g:  19%|█▉        | 251/1326 [00:07<00:13, 78.53it/s]
# Processing: BASC binarized, negative r2g:  20%|█▉        | 260/1326 [00:07<00:13, 80.96it/s]
# Processing: BASC binarized, negative r2g:  20%|██        | 269/1326 [00:07<00:12, 82.80it/s]
# Processing: BASC binarized, negative r2g:  21%|██        | 279/1326 [00:07<00:12, 85.42it/s]
# Processing: BASC binarized, negative r2g:  22%|██▏       | 289/1326 [00:07<00:11, 87.44it/s]
# Processing: BASC binarized, negative r2g:  23%|██▎       | 299/1326 [00:07<00:11, 89.07it/s]
# Processing: BASC binarized, negative r2g:  23%|██▎       | 309/1326 [00:07<00:11, 89.52it/s]
# Processing: BASC binarized, negative r2g:  24%|██▍       | 319/1326 [00:07<00:11, 91.47it/s]
# Processing: BASC binarized, negative r2g:  25%|██▍       | 329/1326 [00:07<00:10, 93.46it/s]
# Processing: BASC binarized, negative r2g:  26%|██▌       | 339/1326 [00:07<00:10, 92.77it/s]
# Processing: BASC binarized, negative r2g:  26%|██▋       | 349/1326 [00:08<00:12, 77.00it/s]
# Processing: BASC binarized, negative r2g:  27%|██▋       | 358/1326 [00:08<00:17, 55.11it/s]
# Processing: BASC binarized, negative r2g:  28%|██▊       | 367/1326 [00:08<00:15, 61.74it/s]
# Processing: BASC binarized, negative r2g:  28%|██▊       | 376/1326 [00:08<00:14, 65.31it/s]
# Processing: BASC binarized, negative r2g:  29%|██▉       | 385/1326 [00:08<00:13, 70.23it/s]
# Processing: BASC binarized, negative r2g:  30%|██▉       | 393/1326 [00:08<00:13, 71.73it/s]
# Processing: BASC binarized, negative r2g:  30%|███       | 401/1326 [00:08<00:12, 73.56it/s]
# Processing: BASC binarized, negative r2g:  31%|███       | 411/1326 [00:09<00:11, 79.82it/s]
# Processing: BASC binarized, negative r2g:  32%|███▏      | 420/1326 [00:09<00:10, 82.54it/s]
# Processing: BASC binarized, negative r2g:  32%|███▏      | 429/1326 [00:09<00:10, 84.06it/s]
# Processing: BASC binarized, negative r2g:  33%|███▎      | 438/1326 [00:09<00:11, 78.37it/s]
# Processing: BASC binarized, negative r2g:  34%|███▎      | 447/1326 [00:09<00:11, 76.52it/s]
# Processing: BASC binarized, negative r2g:  34%|███▍      | 455/1326 [00:09<00:12, 68.99it/s]
# Processing: BASC binarized, negative r2g:  35%|███▍      | 463/1326 [00:09<00:15, 55.46it/s]
# Processing: BASC binarized, negative r2g:  35%|███▌      | 470/1326 [00:10<00:18, 45.45it/s]
# Processing: BASC binarized, negative r2g:  36%|███▌      | 476/1326 [00:10<00:19, 44.55it/s]
# Processing: BASC binarized, negative r2g:  36%|███▋      | 483/1326 [00:10<00:17, 49.05it/s]
# Processing: BASC binarized, negative r2g:  37%|███▋      | 489/1326 [00:10<00:16, 50.87it/s]
# Processing: BASC binarized, negative r2g:  37%|███▋      | 495/1326 [00:10<00:16, 50.56it/s]
# Processing: BASC binarized, negative r2g:  38%|███▊      | 501/1326 [00:10<00:16, 50.60it/s]
# Processing: BASC binarized, negative r2g:  38%|███▊      | 507/1326 [00:10<00:15, 52.64it/s]
# Processing: BASC binarized, negative r2g:  39%|███▉      | 514/1326 [00:10<00:14, 54.94it/s]
# Processing: BASC binarized, negative r2g:  39%|███▉      | 521/1326 [00:11<00:13, 58.18it/s]
# Processing: BASC binarized, negative r2g:  40%|███▉      | 529/1326 [00:11<00:12, 63.89it/s]
# Processing: BASC binarized, negative r2g:  41%|████      | 540/1326 [00:11<00:10, 74.19it/s]
# Processing: BASC binarized, negative r2g:  41%|████▏     | 548/1326 [00:11<00:15, 50.92it/s]
# Processing: BASC binarized, negative r2g:  42%|████▏     | 555/1326 [00:11<00:16, 47.08it/s]
# Processing: BASC binarized, negative r2g:  42%|████▏     | 561/1326 [00:12<00:21, 35.10it/s]
# Processing: BASC binarized, negative r2g:  43%|████▎     | 566/1326 [00:12<00:25, 30.39it/s]
# Processing: BASC binarized, negative r2g:  43%|████▎     | 571/1326 [00:12<00:22, 32.91it/s]
# Processing: BASC binarized, negative r2g:  43%|████▎     | 575/1326 [00:12<00:23, 32.21it/s]
# Processing: BASC binarized, negative r2g:  44%|████▎     | 579/1326 [00:12<00:27, 27.02it/s]
# Processing: BASC binarized, negative r2g:  44%|████▍     | 583/1326 [00:12<00:30, 24.41it/s]
# Processing: BASC binarized, negative r2g:  44%|████▍     | 588/1326 [00:13<00:25, 29.00it/s]
# Processing: BASC binarized, negative r2g:  45%|████▍     | 592/1326 [00:13<00:24, 30.03it/s]
# Processing: BASC binarized, negative r2g:  45%|████▌     | 600/1326 [00:13<00:17, 40.41it/s]
# Processing: BASC binarized, negative r2g:  46%|████▌     | 605/1326 [00:17<02:56,  4.09it/s]
# Processing: BASC binarized, negative r2g:  46%|████▌     | 612/1326 [00:17<01:56,  6.15it/s]
# Processing: BASC binarized, negative r2g:  47%|████▋     | 617/1326 [00:17<01:30,  7.85it/s]
# Processing: BASC binarized, negative r2g:  47%|████▋     | 625/1326 [00:17<00:59, 11.87it/s]
# Processing: BASC binarized, negative r2g:  48%|████▊     | 634/1326 [00:17<00:39, 17.62it/s]
# Processing: BASC binarized, negative r2g:  49%|████▊     | 644/1326 [00:17<00:27, 25.02it/s]
# Processing: BASC binarized, negative r2g:  49%|████▉     | 651/1326 [00:18<00:24, 27.38it/s]
# Processing: BASC binarized, negative r2g:  50%|████▉     | 657/1326 [00:18<00:22, 30.35it/s]
# Processing: BASC binarized, negative r2g:  50%|█████     | 663/1326 [00:18<00:20, 33.13it/s]
# Processing: BASC binarized, negative r2g:  50%|█████     | 669/1326 [00:18<00:20, 31.87it/s]
# Processing: BASC binarized, negative r2g:  51%|█████     | 674/1326 [00:18<00:20, 32.07it/s]
# Processing: BASC binarized, negative r2g:  51%|█████▏    | 680/1326 [00:18<00:17, 36.28it/s]
# Processing: BASC binarized, negative r2g:  52%|█████▏    | 685/1326 [00:19<00:16, 38.43it/s]
# Processing: BASC binarized, negative r2g:  52%|█████▏    | 691/1326 [00:19<00:16, 39.51it/s]
# Processing: BASC binarized, negative r2g:  53%|█████▎    | 698/1326 [00:19<00:13, 45.89it/s]
# Processing: BASC binarized, negative r2g:  53%|█████▎    | 705/1326 [00:19<00:12, 50.94it/s]
# Processing: BASC binarized, negative r2g:  54%|█████▎    | 711/1326 [00:19<00:12, 49.22it/s]
# Processing: BASC binarized, negative r2g:  54%|█████▍    | 717/1326 [00:19<00:13, 44.97it/s]
# Processing: BASC binarized, negative r2g:  54%|█████▍    | 722/1326 [00:19<00:13, 44.93it/s]
# Processing: BASC binarized, negative r2g:  55%|█████▍    | 728/1326 [00:19<00:12, 46.85it/s]
# Processing: BASC binarized, negative r2g:  55%|█████▌    | 733/1326 [00:19<00:12, 46.67it/s]
# Processing: BASC binarized, negative r2g:  56%|█████▌    | 738/1326 [00:20<00:12, 47.51it/s]
# Processing: BASC binarized, negative r2g:  56%|█████▌    | 744/1326 [00:20<00:12, 48.49it/s]
# Processing: BASC binarized, negative r2g:  56%|█████▋    | 749/1326 [00:20<00:14, 40.14it/s]
# Processing: BASC binarized, negative r2g:  57%|█████▋    | 755/1326 [00:20<00:13, 41.36it/s]
# Processing: BASC binarized, negative r2g:  57%|█████▋    | 760/1326 [00:20<00:16, 35.11it/s]
# Processing: BASC binarized, negative r2g:  58%|█████▊    | 765/1326 [00:20<00:14, 38.03it/s]
# Processing: BASC binarized, negative r2g:  58%|█████▊    | 771/1326 [00:20<00:13, 40.93it/s]
# Processing: BASC binarized, negative r2g:  59%|█████▊    | 776/1326 [00:21<00:14, 36.74it/s]
# Processing: BASC binarized, negative r2g:  59%|█████▉    | 780/1326 [00:21<00:17, 31.96it/s]
# Processing: BASC binarized, negative r2g:  59%|█████▉    | 784/1326 [00:21<00:17, 30.11it/s]
# Processing: BASC binarized, negative r2g:  59%|█████▉    | 788/1326 [00:21<00:18, 29.25it/s]
# Processing: BASC binarized, negative r2g:  60%|█████▉    | 794/1326 [00:21<00:15, 34.84it/s]
# Processing: BASC binarized, negative r2g:  60%|██████    | 800/1326 [00:21<00:13, 38.89it/s]
# Processing: BASC binarized, negative r2g:  61%|██████    | 805/1326 [00:21<00:14, 36.66it/s]
# Processing: BASC binarized, negative r2g:  61%|██████    | 809/1326 [00:22<00:16, 31.89it/s]
# Processing: BASC binarized, negative r2g:  61%|██████▏   | 813/1326 [00:22<00:16, 31.41it/s]
# Processing: BASC binarized, negative r2g:  62%|██████▏   | 817/1326 [00:22<00:17, 28.61it/s]
# Processing: BASC binarized, negative r2g:  62%|██████▏   | 822/1326 [00:22<00:15, 33.05it/s]
# Processing: BASC binarized, negative r2g:  63%|██████▎   | 829/1326 [00:22<00:12, 40.65it/s]
# Processing: BASC binarized, negative r2g:  63%|██████▎   | 837/1326 [00:22<00:09, 49.24it/s]
# Processing: BASC binarized, negative r2g:  64%|██████▍   | 846/1326 [00:22<00:08, 58.96it/s]
# Processing: BASC binarized, negative r2g:  64%|██████▍   | 853/1326 [00:23<00:07, 59.91it/s]
# Processing: BASC binarized, negative r2g:  65%|██████▍   | 861/1326 [00:23<00:07, 63.67it/s]
# Processing: BASC binarized, negative r2g:  66%|██████▌   | 869/1326 [00:23<00:07, 63.62it/s]
# Processing: BASC binarized, negative r2g:  66%|██████▌   | 876/1326 [00:23<00:07, 61.38it/s]
# Processing: BASC binarized, negative r2g:  67%|██████▋   | 884/1326 [00:23<00:06, 64.31it/s]
# Processing: BASC binarized, negative r2g:  67%|██████▋   | 891/1326 [00:23<00:06, 65.63it/s]
# Processing: BASC binarized, negative r2g:  68%|██████▊   | 898/1326 [00:23<00:06, 65.81it/s]
# Processing: BASC binarized, negative r2g:  68%|██████▊   | 908/1326 [00:23<00:05, 75.05it/s]
# Processing: BASC binarized, negative r2g:  69%|██████▉   | 916/1326 [00:23<00:06, 63.21it/s]
# Processing: BASC binarized, negative r2g:  70%|██████▉   | 926/1326 [00:24<00:05, 72.09it/s]
# Processing: BASC binarized, negative r2g:  70%|███████   | 934/1326 [00:24<00:05, 68.92it/s]
# Processing: BASC binarized, negative r2g:  71%|███████   | 943/1326 [00:24<00:05, 68.80it/s]
# Processing: BASC binarized, negative r2g:  72%|███████▏  | 953/1326 [00:24<00:04, 75.27it/s]
# Processing: BASC binarized, negative r2g:  72%|███████▏  | 961/1326 [00:24<00:04, 73.40it/s]
# Processing: BASC binarized, negative r2g:  73%|███████▎  | 972/1326 [00:24<00:04, 82.63it/s]
# Processing: BASC binarized, negative r2g:  74%|███████▍  | 981/1326 [00:24<00:04, 79.81it/s]
# Processing: BASC binarized, negative r2g:  75%|███████▍  | 990/1326 [00:25<00:06, 49.74it/s]
# Processing: BASC binarized, negative r2g:  75%|███████▌  | 997/1326 [00:25<00:07, 46.55it/s]
# Processing: BASC binarized, negative r2g:  76%|███████▌  | 1003/1326 [00:25<00:07, 43.66it/s]
# Processing: BASC binarized, negative r2g:  76%|███████▌  | 1009/1326 [00:25<00:07, 44.28it/s]
# Processing: BASC binarized, negative r2g:  76%|███████▋  | 1014/1326 [00:25<00:07, 42.47it/s]
# Processing: BASC binarized, negative r2g:  77%|███████▋  | 1019/1326 [00:25<00:09, 33.45it/s]
# Processing: BASC binarized, negative r2g:  77%|███████▋  | 1023/1326 [00:26<00:08, 33.83it/s]
# Processing: BASC binarized, negative r2g:  78%|███████▊  | 1028/1326 [00:26<00:08, 36.07it/s]
# Processing: BASC binarized, negative r2g:  78%|███████▊  | 1032/1326 [00:26<00:08, 35.70it/s]
# Processing: BASC binarized, negative r2g:  78%|███████▊  | 1037/1326 [00:26<00:07, 37.70it/s]
# Processing: BASC binarized, negative r2g:  79%|███████▊  | 1041/1326 [00:26<00:08, 33.36it/s]
# Processing: BASC binarized, negative r2g:  79%|███████▉  | 1046/1326 [00:26<00:07, 35.58it/s]
# Processing: BASC binarized, negative r2g:  79%|███████▉  | 1050/1326 [00:26<00:07, 34.89it/s]
# Processing: BASC binarized, negative r2g:  80%|███████▉  | 1056/1326 [00:26<00:06, 39.56it/s]
# Processing: BASC binarized, negative r2g:  80%|████████  | 1061/1326 [00:27<00:06, 40.08it/s]
# Processing: BASC binarized, negative r2g:  80%|████████  | 1066/1326 [00:27<00:11, 23.27it/s]
# Processing: BASC binarized, negative r2g:  81%|████████  | 1070/1326 [00:27<00:13, 18.69it/s]
# Processing: BASC binarized, negative r2g:  81%|████████  | 1073/1326 [00:28<00:16, 15.08it/s]
# Processing: BASC binarized, negative r2g:  81%|████████  | 1076/1326 [00:28<00:16, 15.14it/s]
# Processing: BASC binarized, negative r2g:  81%|████████▏ | 1080/1326 [00:28<00:13, 18.13it/s]
# Processing: BASC binarized, negative r2g:  82%|████████▏ | 1083/1326 [00:28<00:12, 19.98it/s]
# Processing: BASC binarized, negative r2g:  82%|████████▏ | 1086/1326 [00:28<00:12, 19.66it/s]
# Processing: BASC binarized, negative r2g:  82%|████████▏ | 1089/1326 [00:28<00:11, 20.36it/s]
# Processing: BASC binarized, negative r2g:  82%|████████▏ | 1092/1326 [00:29<00:10, 21.31it/s]
# Processing: BASC binarized, negative r2g:  83%|████████▎ | 1096/1326 [00:29<00:09, 25.12it/s]
# Processing: BASC binarized, negative r2g:  83%|████████▎ | 1099/1326 [00:29<00:08, 26.09it/s]
# Processing: BASC binarized, negative r2g:  83%|████████▎ | 1102/1326 [00:29<00:08, 26.74it/s]
# Processing: BASC binarized, negative r2g:  83%|████████▎ | 1105/1326 [00:29<00:09, 24.37it/s]
# Processing: BASC binarized, negative r2g:  84%|████████▎ | 1109/1326 [00:29<00:08, 25.84it/s]
# Processing: BASC binarized, negative r2g:  84%|████████▍ | 1112/1326 [00:29<00:09, 23.12it/s]
# Processing: BASC binarized, negative r2g:  84%|████████▍ | 1116/1326 [00:29<00:08, 26.21it/s]
# Processing: BASC binarized, negative r2g:  85%|████████▍ | 1121/1326 [00:30<00:06, 31.00it/s]
# Processing: BASC binarized, negative r2g:  85%|████████▍ | 1125/1326 [00:30<00:06, 32.52it/s]
# Processing: BASC binarized, negative r2g:  85%|████████▌ | 1129/1326 [00:30<00:05, 33.95it/s]
# Processing: BASC binarized, negative r2g:  86%|████████▌ | 1134/1326 [00:30<00:05, 37.83it/s]
# Processing: BASC binarized, negative r2g:  86%|████████▌ | 1140/1326 [00:30<00:04, 41.96it/s]
# Processing: BASC binarized, negative r2g:  86%|████████▋ | 1145/1326 [00:30<00:05, 31.61it/s]
# Processing: BASC binarized, negative r2g:  87%|████████▋ | 1149/1326 [00:30<00:06, 25.72it/s]
# Processing: BASC binarized, negative r2g:  87%|████████▋ | 1154/1326 [00:31<00:05, 29.37it/s]
# Processing: BASC binarized, negative r2g:  87%|████████▋ | 1158/1326 [00:31<00:06, 26.68it/s]
# Processing: BASC binarized, negative r2g:  88%|████████▊ | 1162/1326 [00:31<00:05, 27.54it/s]
# Processing: BASC binarized, negative r2g:  88%|████████▊ | 1167/1326 [00:31<00:05, 29.43it/s]
# Processing: BASC binarized, negative r2g:  88%|████████▊ | 1171/1326 [00:31<00:06, 24.76it/s]
# Processing: BASC binarized, negative r2g:  89%|████████▊ | 1175/1326 [00:31<00:05, 27.30it/s]
# Processing: BASC binarized, negative r2g:  89%|████████▉ | 1180/1326 [00:31<00:04, 30.77it/s]
# Processing: BASC binarized, negative r2g:  89%|████████▉ | 1184/1326 [00:32<00:04, 31.04it/s]
# Processing: BASC binarized, negative r2g:  90%|████████▉ | 1188/1326 [00:32<00:04, 32.74it/s]
# Processing: BASC binarized, negative r2g:  90%|█████████ | 1194/1326 [00:32<00:03, 39.49it/s]
# Processing: BASC binarized, negative r2g:  90%|█████████ | 1199/1326 [00:32<00:03, 40.12it/s]
# Processing: BASC binarized, negative r2g:  91%|█████████ | 1205/1326 [00:32<00:02, 44.97it/s]
# Processing: BASC binarized, negative r2g:  91%|█████████▏| 1211/1326 [00:32<00:02, 47.49it/s]
# Processing: BASC binarized, negative r2g:  92%|█████████▏| 1216/1326 [00:32<00:02, 46.94it/s]
# Processing: BASC binarized, negative r2g:  92%|█████████▏| 1224/1326 [00:32<00:01, 55.27it/s]
# Processing: BASC binarized, negative r2g:  93%|█████████▎| 1230/1326 [00:33<00:02, 46.35it/s]
# Processing: BASC binarized, negative r2g:  93%|█████████▎| 1235/1326 [00:33<00:02, 45.20it/s]
# Processing: BASC binarized, negative r2g:  94%|█████████▎| 1240/1326 [00:33<00:02, 38.75it/s]
# Processing: BASC binarized, negative r2g:  94%|█████████▍| 1245/1326 [00:33<00:02, 36.10it/s]
# Processing: BASC binarized, negative r2g:  94%|█████████▍| 1249/1326 [00:33<00:02, 35.42it/s]
# Processing: BASC binarized, negative r2g:  94%|█████████▍| 1253/1326 [00:33<00:02, 34.01it/s]
# Processing: BASC binarized, negative r2g:  95%|█████████▍| 1258/1326 [00:33<00:01, 37.19it/s]
# Processing: BASC binarized, negative r2g:  95%|█████████▌| 1263/1326 [00:33<00:01, 40.02it/s]
# Processing: BASC binarized, negative r2g:  96%|█████████▌| 1268/1326 [00:34<00:01, 30.31it/s]
# Processing: BASC binarized, negative r2g:  96%|█████████▌| 1273/1326 [00:34<00:01, 33.33it/s]
# Processing: BASC binarized, negative r2g:  96%|█████████▋| 1277/1326 [00:34<00:01, 34.28it/s]
# Processing: BASC binarized, negative r2g:  97%|█████████▋| 1281/1326 [00:34<00:01, 28.47it/s]
# Processing: BASC binarized, negative r2g:  97%|█████████▋| 1285/1326 [00:34<00:01, 30.22it/s]
# Processing: BASC binarized, negative r2g:  97%|█████████▋| 1291/1326 [00:34<00:00, 35.91it/s]
# Processing: BASC binarized, negative r2g:  98%|█████████▊| 1297/1326 [00:34<00:00, 41.41it/s]
# Processing: BASC binarized, negative r2g:  98%|█████████▊| 1303/1326 [00:35<00:00, 42.67it/s]
# Processing: BASC binarized, negative r2g:  99%|█████████▊| 1308/1326 [00:35<00:00, 43.08it/s]
# Processing: BASC binarized, negative r2g:  99%|█████████▉| 1316/1326 [00:35<00:00, 50.27it/s]
# Processing: BASC binarized, negative r2g: 100%|█████████▉| 1323/1326 [00:35<00:00, 53.46it/s]
#  50%|█████     | 7/14 [04:31<05:25, 46.52s/it]
# Processing: 0.85 quantile, positive r2g:   0%|          | 0/1326 [00:00<?, ?it/s]
# Processing: 0.85 quantile, positive r2g:   1%|          | 10/1326 [00:00<00:13, 98.26it/s]
# Processing: 0.85 quantile, positive r2g:   2%|▏         | 20/1326 [00:00<00:17, 74.11it/s]
# Processing: 0.85 quantile, positive r2g:   2%|▏         | 29/1326 [00:00<00:16, 79.27it/s]
# Processing: 0.85 quantile, positive r2g:   3%|▎         | 38/1326 [00:00<00:15, 81.47it/s]
# Processing: 0.85 quantile, positive r2g:   4%|▎         | 47/1326 [00:00<00:17, 72.97it/s]
# Processing: 0.85 quantile, positive r2g:   4%|▍         | 55/1326 [00:00<00:18, 68.96it/s]
# Processing: 0.85 quantile, positive r2g:   5%|▍         | 65/1326 [00:00<00:16, 75.98it/s]
# Processing: 0.85 quantile, positive r2g:   6%|▌         | 73/1326 [00:01<00:21, 58.48it/s]
# Processing: 0.85 quantile, positive r2g:   6%|▌         | 80/1326 [00:01<00:24, 50.39it/s]
# Processing: 0.85 quantile, positive r2g:   6%|▋         | 86/1326 [00:01<00:33, 37.47it/s]
# Processing: 0.85 quantile, positive r2g:   7%|▋         | 91/1326 [00:01<00:33, 37.06it/s]
# Processing: 0.85 quantile, positive r2g:   7%|▋         | 96/1326 [00:01<00:37, 33.03it/s]
# Processing: 0.85 quantile, positive r2g:   8%|▊         | 100/1326 [00:02<00:41, 29.45it/s]
# Processing: 0.85 quantile, positive r2g:   8%|▊         | 104/1326 [00:02<00:49, 24.61it/s]
# Processing: 0.85 quantile, positive r2g:   8%|▊         | 107/1326 [00:02<00:49, 24.60it/s]
# Processing: 0.85 quantile, positive r2g:   8%|▊         | 111/1326 [00:02<00:46, 26.27it/s]
# Processing: 0.85 quantile, positive r2g:   9%|▊         | 114/1326 [00:02<00:55, 21.71it/s]
# Processing: 0.85 quantile, positive r2g:   9%|▉         | 122/1326 [00:02<00:37, 31.69it/s]
# Processing: 0.85 quantile, positive r2g:  10%|▉         | 128/1326 [00:03<00:32, 36.49it/s]
# Processing: 0.85 quantile, positive r2g:  10%|█         | 133/1326 [00:03<00:30, 38.98it/s]
# Processing: 0.85 quantile, positive r2g:  10%|█         | 138/1326 [00:03<00:30, 39.53it/s]
# Processing: 0.85 quantile, positive r2g:  11%|█         | 144/1326 [00:03<00:27, 43.39it/s]
# Processing: 0.85 quantile, positive r2g:  11%|█▏        | 150/1326 [00:03<00:25, 46.39it/s]
# Processing: 0.85 quantile, positive r2g:  12%|█▏        | 156/1326 [00:03<00:23, 49.56it/s]
# Processing: 0.85 quantile, positive r2g:  12%|█▏        | 162/1326 [00:03<00:23, 50.33it/s]
# Processing: 0.85 quantile, positive r2g:  13%|█▎        | 168/1326 [00:03<00:22, 50.72it/s]
# Processing: 0.85 quantile, positive r2g:  13%|█▎        | 174/1326 [00:04<00:28, 40.58it/s]
# Processing: 0.85 quantile, positive r2g:  13%|█▎        | 179/1326 [00:04<00:39, 28.80it/s]
# Processing: 0.85 quantile, positive r2g:  14%|█▍        | 183/1326 [00:04<00:39, 28.81it/s]
# Processing: 0.85 quantile, positive r2g:  14%|█▍        | 188/1326 [00:04<00:36, 31.61it/s]
# Processing: 0.85 quantile, positive r2g:  14%|█▍        | 192/1326 [00:04<00:35, 32.07it/s]
# Processing: 0.85 quantile, positive r2g:  15%|█▍        | 196/1326 [00:04<00:34, 32.84it/s]
# Processing: 0.85 quantile, positive r2g:  15%|█▌        | 201/1326 [00:04<00:31, 35.63it/s]
# Processing: 0.85 quantile, positive r2g:  16%|█▌        | 213/1326 [00:05<00:20, 54.53it/s]
# Processing: 0.85 quantile, positive r2g:  17%|█▋        | 220/1326 [00:05<00:19, 57.41it/s]
# Processing: 0.85 quantile, positive r2g:  17%|█▋        | 230/1326 [00:05<00:16, 66.96it/s]
# Processing: 0.85 quantile, positive r2g:  18%|█▊        | 241/1326 [00:05<00:14, 77.47it/s]
# Processing: 0.85 quantile, positive r2g:  19%|█▉        | 251/1326 [00:05<00:13, 78.17it/s]
# Processing: 0.85 quantile, positive r2g:  20%|█▉        | 260/1326 [00:05<00:13, 78.20it/s]
# Processing: 0.85 quantile, positive r2g:  20%|██        | 268/1326 [00:05<00:16, 65.24it/s]
# Processing: 0.85 quantile, positive r2g:  21%|██        | 275/1326 [00:05<00:17, 58.41it/s]
# Processing: 0.85 quantile, positive r2g:  21%|██▏       | 282/1326 [00:06<00:18, 57.96it/s]
# Processing: 0.85 quantile, positive r2g:  22%|██▏       | 289/1326 [00:06<00:19, 54.19it/s]
# Processing: 0.85 quantile, positive r2g:  22%|██▏       | 295/1326 [00:06<00:18, 54.52it/s]
# Processing: 0.85 quantile, positive r2g:  23%|██▎       | 303/1326 [00:06<00:17, 59.20it/s]
# Processing: 0.85 quantile, positive r2g:  23%|██▎       | 311/1326 [00:06<00:16, 62.86it/s]
# Processing: 0.85 quantile, positive r2g:  24%|██▍       | 319/1326 [00:06<00:15, 65.42it/s]
# Processing: 0.85 quantile, positive r2g:  25%|██▍       | 327/1326 [00:06<00:14, 67.82it/s]
# Processing: 0.85 quantile, positive r2g:  25%|██▌       | 335/1326 [00:06<00:13, 70.97it/s]
# Processing: 0.85 quantile, positive r2g:  26%|██▌       | 343/1326 [00:07<00:15, 63.18it/s]
# Processing: 0.85 quantile, positive r2g:  26%|██▋       | 350/1326 [00:07<00:25, 38.51it/s]
# Processing: 0.85 quantile, positive r2g:  27%|██▋       | 356/1326 [00:07<00:39, 24.33it/s]
# Processing: 0.85 quantile, positive r2g:  27%|██▋       | 361/1326 [00:08<00:34, 27.60it/s]
# Processing: 0.85 quantile, positive r2g:  28%|██▊       | 367/1326 [00:08<00:29, 32.10it/s]
# Processing: 0.85 quantile, positive r2g:  28%|██▊       | 373/1326 [00:08<00:26, 36.64it/s]
# Processing: 0.85 quantile, positive r2g:  29%|██▊       | 378/1326 [00:08<00:24, 38.40it/s]
# Processing: 0.85 quantile, positive r2g:  29%|██▉       | 387/1326 [00:08<00:19, 49.30it/s]
# Processing: 0.85 quantile, positive r2g:  30%|██▉       | 395/1326 [00:08<00:16, 56.16it/s]
# Processing: 0.85 quantile, positive r2g:  30%|███       | 404/1326 [00:08<00:14, 63.44it/s]
# Processing: 0.85 quantile, positive r2g:  31%|███       | 414/1326 [00:08<00:12, 72.81it/s]
# Processing: 0.85 quantile, positive r2g:  32%|███▏      | 423/1326 [00:08<00:11, 75.82it/s]
# Processing: 0.85 quantile, positive r2g:  33%|███▎      | 432/1326 [00:09<00:17, 52.03it/s]
# Processing: 0.85 quantile, positive r2g:  33%|███▎      | 439/1326 [00:09<00:17, 52.13it/s]
# Processing: 0.85 quantile, positive r2g:  34%|███▎      | 446/1326 [00:09<00:17, 50.14it/s]
# Processing: 0.85 quantile, positive r2g:  34%|███▍      | 452/1326 [00:09<00:18, 46.22it/s]
# Processing: 0.85 quantile, positive r2g:  35%|███▍      | 458/1326 [00:09<00:20, 42.58it/s]
# Processing: 0.85 quantile, positive r2g:  35%|███▌      | 466/1326 [00:09<00:17, 49.49it/s]
# Processing: 0.85 quantile, positive r2g:  36%|███▌      | 472/1326 [00:10<00:16, 50.60it/s]
# Processing: 0.85 quantile, positive r2g:  36%|███▌      | 480/1326 [00:10<00:14, 57.29it/s]
# Processing: 0.85 quantile, positive r2g:  37%|███▋      | 489/1326 [00:10<00:13, 61.97it/s]
# Processing: 0.85 quantile, positive r2g:  37%|███▋      | 496/1326 [00:10<00:13, 60.40it/s]
# Processing: 0.85 quantile, positive r2g:  38%|███▊      | 503/1326 [00:10<00:13, 59.85it/s]
# Processing: 0.85 quantile, positive r2g:  38%|███▊      | 510/1326 [00:10<00:13, 61.96it/s]
# Processing: 0.85 quantile, positive r2g:  39%|███▉      | 517/1326 [00:10<00:13, 59.05it/s]
# Processing: 0.85 quantile, positive r2g:  40%|███▉      | 524/1326 [00:10<00:13, 61.18it/s]
# Processing: 0.85 quantile, positive r2g:  40%|████      | 531/1326 [00:10<00:12, 63.36it/s]
# Processing: 0.85 quantile, positive r2g:  41%|████      | 541/1326 [00:11<00:10, 72.99it/s]
# Processing: 0.85 quantile, positive r2g:  41%|████▏     | 549/1326 [00:11<00:23, 32.95it/s]
# Processing: 0.85 quantile, positive r2g:  42%|████▏     | 555/1326 [00:11<00:27, 28.17it/s]
# Processing: 0.85 quantile, positive r2g:  42%|████▏     | 560/1326 [00:12<00:36, 20.89it/s]
# Processing: 0.85 quantile, positive r2g:  43%|████▎     | 564/1326 [00:12<00:50, 15.14it/s]
# Processing: 0.85 quantile, positive r2g:  43%|████▎     | 567/1326 [00:12<00:46, 16.35it/s]
# Processing: 0.85 quantile, positive r2g:  43%|████▎     | 571/1326 [00:13<00:41, 18.11it/s]
# Processing: 0.85 quantile, positive r2g:  43%|████▎     | 574/1326 [00:13<00:48, 15.54it/s]
# Processing: 0.85 quantile, positive r2g:  44%|████▎     | 577/1326 [00:13<00:59, 12.67it/s]
# Processing: 0.85 quantile, positive r2g:  44%|████▎     | 579/1326 [00:13<00:58, 12.82it/s]
# Processing: 0.85 quantile, positive r2g:  44%|████▍     | 581/1326 [00:14<00:58, 12.69it/s]
# Processing: 0.85 quantile, positive r2g:  44%|████▍     | 583/1326 [00:14<00:59, 12.40it/s]
# Processing: 0.85 quantile, positive r2g:  44%|████▍     | 587/1326 [00:14<00:43, 16.90it/s]
# Processing: 0.85 quantile, positive r2g:  44%|████▍     | 590/1326 [00:14<00:37, 19.38it/s]
# Processing: 0.85 quantile, positive r2g:  45%|████▍     | 594/1326 [00:14<00:32, 22.83it/s]
# Processing: 0.85 quantile, positive r2g:  45%|████▌     | 601/1326 [00:14<00:22, 32.89it/s]
# Processing: 0.85 quantile, positive r2g:  46%|████▌     | 608/1326 [00:14<00:17, 41.42it/s]
# Processing: 0.85 quantile, positive r2g:  46%|████▌     | 613/1326 [00:15<00:23, 29.81it/s]
# Processing: 0.85 quantile, positive r2g:  47%|████▋     | 617/1326 [00:15<00:27, 25.37it/s]
# Processing: 0.85 quantile, positive r2g:  47%|████▋     | 621/1326 [00:15<00:27, 25.90it/s]
# Processing: 0.85 quantile, positive r2g:  47%|████▋     | 625/1326 [00:15<00:25, 27.69it/s]
# Processing: 0.85 quantile, positive r2g:  48%|████▊     | 630/1326 [00:15<00:22, 31.47it/s]
# Processing: 0.85 quantile, positive r2g:  48%|████▊     | 634/1326 [00:15<00:23, 30.05it/s]
# Processing: 0.85 quantile, positive r2g:  48%|████▊     | 638/1326 [00:16<00:22, 30.08it/s]
# Processing: 0.85 quantile, positive r2g:  48%|████▊     | 643/1326 [00:16<00:19, 34.27it/s]
# Processing: 0.85 quantile, positive r2g:  49%|████▉     | 647/1326 [00:16<00:21, 31.14it/s]
# Processing: 0.85 quantile, positive r2g:  49%|████▉     | 651/1326 [00:16<00:20, 32.67it/s]
# Processing: 0.85 quantile, positive r2g:  49%|████▉     | 656/1326 [00:16<00:18, 36.78it/s]
# Processing: 0.85 quantile, positive r2g:  50%|████▉     | 662/1326 [00:16<00:15, 41.87it/s]
# Processing: 0.85 quantile, positive r2g:  50%|█████     | 667/1326 [00:16<00:17, 37.86it/s]
# Processing: 0.85 quantile, positive r2g:  51%|█████     | 672/1326 [00:16<00:16, 39.72it/s]
# Processing: 0.85 quantile, positive r2g:  51%|█████     | 678/1326 [00:16<00:14, 43.48it/s]
# Processing: 0.85 quantile, positive r2g:  52%|█████▏    | 684/1326 [00:17<00:13, 46.70it/s]
# Processing: 0.85 quantile, positive r2g:  52%|█████▏    | 691/1326 [00:17<00:13, 48.11it/s]
# Processing: 0.85 quantile, positive r2g:  53%|█████▎    | 699/1326 [00:17<00:11, 56.20it/s]
# Processing: 0.85 quantile, positive r2g:  53%|█████▎    | 706/1326 [00:17<00:10, 59.65it/s]
# Processing: 0.85 quantile, positive r2g:  54%|█████▍    | 716/1326 [00:17<00:08, 70.10it/s]
# Processing: 0.85 quantile, positive r2g:  55%|█████▍    | 728/1326 [00:17<00:07, 81.94it/s]
# Processing: 0.85 quantile, positive r2g:  56%|█████▌    | 739/1326 [00:17<00:06, 87.29it/s]
# Processing: 0.85 quantile, positive r2g:  56%|█████▋    | 748/1326 [00:17<00:07, 76.22it/s]
# Processing: 0.85 quantile, positive r2g:  57%|█████▋    | 756/1326 [00:18<00:09, 62.93it/s]
# Processing: 0.85 quantile, positive r2g:  58%|█████▊    | 763/1326 [00:18<00:11, 49.54it/s]
# Processing: 0.85 quantile, positive r2g:  58%|█████▊    | 770/1326 [00:18<00:10, 51.81it/s]
# Processing: 0.85 quantile, positive r2g:  59%|█████▊    | 776/1326 [00:18<00:12, 45.39it/s]
# Processing: 0.85 quantile, positive r2g:  59%|█████▉    | 782/1326 [00:18<00:16, 33.09it/s]
# Processing: 0.85 quantile, positive r2g:  59%|█████▉    | 787/1326 [00:19<00:21, 25.40it/s]
# Processing: 0.85 quantile, positive r2g:  60%|█████▉    | 791/1326 [00:19<00:22, 23.70it/s]
# Processing: 0.85 quantile, positive r2g:  60%|█████▉    | 795/1326 [00:19<00:20, 25.94it/s]
# Processing: 0.85 quantile, positive r2g:  60%|██████    | 800/1326 [00:19<00:17, 29.73it/s]
# Processing: 0.85 quantile, positive r2g:  61%|██████    | 804/1326 [00:19<00:16, 31.10it/s]
# Processing: 0.85 quantile, positive r2g:  61%|██████    | 808/1326 [00:20<00:17, 29.02it/s]
# Processing: 0.85 quantile, positive r2g:  61%|██████    | 812/1326 [00:20<00:19, 25.86it/s]
# Processing: 0.85 quantile, positive r2g:  61%|██████▏   | 815/1326 [00:20<00:22, 23.08it/s]
# Processing: 0.85 quantile, positive r2g:  62%|██████▏   | 819/1326 [00:20<00:20, 25.08it/s]
# Processing: 0.85 quantile, positive r2g:  62%|██████▏   | 823/1326 [00:20<00:18, 27.11it/s]
# Processing: 0.85 quantile, positive r2g:  62%|██████▏   | 828/1326 [00:20<00:15, 31.51it/s]
# Processing: 0.85 quantile, positive r2g:  63%|██████▎   | 833/1326 [00:20<00:14, 34.04it/s]
# Processing: 0.85 quantile, positive r2g:  63%|██████▎   | 838/1326 [00:20<00:13, 36.33it/s]
# Processing: 0.85 quantile, positive r2g:  64%|██████▎   | 843/1326 [00:21<00:12, 39.47it/s]
# Processing: 0.85 quantile, positive r2g:  64%|██████▍   | 848/1326 [00:21<00:13, 34.85it/s]
# Processing: 0.85 quantile, positive r2g:  64%|██████▍   | 853/1326 [00:21<00:12, 37.40it/s]
# Processing: 0.85 quantile, positive r2g:  65%|██████▍   | 857/1326 [00:21<00:12, 37.72it/s]
# Processing: 0.85 quantile, positive r2g:  65%|██████▍   | 861/1326 [00:21<00:13, 34.75it/s]
# Processing: 0.85 quantile, positive r2g:  65%|██████▌   | 866/1326 [00:21<00:12, 35.92it/s]
# Processing: 0.85 quantile, positive r2g:  66%|██████▌   | 870/1326 [00:21<00:13, 33.94it/s]
# Processing: 0.85 quantile, positive r2g:  66%|██████▌   | 874/1326 [00:22<00:14, 31.45it/s]
# Processing: 0.85 quantile, positive r2g:  66%|██████▋   | 879/1326 [00:22<00:12, 35.29it/s]
# Processing: 0.85 quantile, positive r2g:  67%|██████▋   | 884/1326 [00:22<00:11, 38.21it/s]
# Processing: 0.85 quantile, positive r2g:  67%|██████▋   | 890/1326 [00:22<00:10, 43.49it/s]
# Processing: 0.85 quantile, positive r2g:  68%|██████▊   | 898/1326 [00:22<00:08, 52.89it/s]
# Processing: 0.85 quantile, positive r2g:  68%|██████▊   | 905/1326 [00:22<00:07, 56.18it/s]
# Processing: 0.85 quantile, positive r2g:  69%|██████▊   | 911/1326 [00:22<00:08, 47.78it/s]
# Processing: 0.85 quantile, positive r2g:  69%|██████▉   | 917/1326 [00:22<00:10, 37.70it/s]
# Processing: 0.85 quantile, positive r2g:  70%|██████▉   | 923/1326 [00:23<00:09, 42.23it/s]
# Processing: 0.85 quantile, positive r2g:  70%|██████▉   | 928/1326 [00:23<00:10, 39.05it/s]
# Processing: 0.85 quantile, positive r2g:  70%|███████   | 933/1326 [00:23<00:10, 37.40it/s]
# Processing: 0.85 quantile, positive r2g:  71%|███████   | 938/1326 [00:23<00:09, 38.85it/s]
# Processing: 0.85 quantile, positive r2g:  71%|███████   | 943/1326 [00:23<00:10, 35.77it/s]
# Processing: 0.85 quantile, positive r2g:  71%|███████▏  | 948/1326 [00:23<00:09, 38.59it/s]
# Processing: 0.85 quantile, positive r2g:  72%|███████▏  | 954/1326 [00:23<00:08, 43.32it/s]
# Processing: 0.85 quantile, positive r2g:  72%|███████▏  | 960/1326 [00:23<00:07, 46.10it/s]
# Processing: 0.85 quantile, positive r2g:  73%|███████▎  | 967/1326 [00:24<00:07, 51.06it/s]
# Processing: 0.85 quantile, positive r2g:  74%|███████▎  | 975/1326 [00:24<00:06, 57.40it/s]
# Processing: 0.85 quantile, positive r2g:  74%|███████▍  | 981/1326 [00:24<00:06, 56.25it/s]
# Processing: 0.85 quantile, positive r2g:  74%|███████▍  | 987/1326 [00:24<00:06, 54.89it/s]
# Processing: 0.85 quantile, positive r2g:  75%|███████▍  | 993/1326 [00:24<00:05, 55.78it/s]
# Processing: 0.85 quantile, positive r2g:  75%|███████▌  | 1001/1326 [00:24<00:05, 60.49it/s]
# Processing: 0.85 quantile, positive r2g:  76%|███████▌  | 1011/1326 [00:24<00:04, 70.29it/s]
# Processing: 0.85 quantile, positive r2g:  77%|███████▋  | 1019/1326 [00:24<00:04, 62.45it/s]
# Processing: 0.85 quantile, positive r2g:  78%|███████▊  | 1029/1326 [00:25<00:04, 70.34it/s]
# Processing: 0.85 quantile, positive r2g:  78%|███████▊  | 1038/1326 [00:25<00:03, 72.36it/s]
# Processing: 0.85 quantile, positive r2g:  79%|███████▉  | 1046/1326 [00:25<00:04, 63.74it/s]
# Processing: 0.85 quantile, positive r2g:  79%|███████▉  | 1053/1326 [00:25<00:05, 51.88it/s]
# Processing: 0.85 quantile, positive r2g:  80%|███████▉  | 1059/1326 [00:25<00:05, 49.44it/s]
# Processing: 0.85 quantile, positive r2g:  80%|████████  | 1065/1326 [00:25<00:07, 34.03it/s]
# Processing: 0.85 quantile, positive r2g:  81%|████████  | 1070/1326 [00:26<00:09, 25.95it/s]
# Processing: 0.85 quantile, positive r2g:  81%|████████  | 1074/1326 [00:26<00:13, 18.17it/s]
# Processing: 0.85 quantile, positive r2g:  81%|████████  | 1077/1326 [00:26<00:13, 18.40it/s]
# Processing: 0.85 quantile, positive r2g:  81%|████████▏ | 1080/1326 [00:27<00:13, 18.35it/s]
# Processing: 0.85 quantile, positive r2g:  82%|████████▏ | 1083/1326 [00:27<00:13, 18.19it/s]
# Processing: 0.85 quantile, positive r2g:  82%|████████▏ | 1086/1326 [00:27<00:14, 16.67it/s]
# Processing: 0.85 quantile, positive r2g:  82%|████████▏ | 1089/1326 [00:27<00:13, 17.82it/s]
# Processing: 0.85 quantile, positive r2g:  82%|████████▏ | 1092/1326 [00:27<00:12, 19.38it/s]
# Processing: 0.85 quantile, positive r2g:  83%|████████▎ | 1097/1326 [00:27<00:09, 24.97it/s]
# Processing: 0.85 quantile, positive r2g:  83%|████████▎ | 1102/1326 [00:27<00:07, 30.35it/s]
# Processing: 0.85 quantile, positive r2g:  83%|████████▎ | 1106/1326 [00:28<00:07, 30.84it/s]
# Processing: 0.85 quantile, positive r2g:  84%|████████▍ | 1111/1326 [00:28<00:06, 34.05it/s]
# Processing: 0.85 quantile, positive r2g:  84%|████████▍ | 1117/1326 [00:28<00:05, 40.32it/s]
# Processing: 0.85 quantile, positive r2g:  85%|████████▍ | 1127/1326 [00:28<00:03, 54.33it/s]
# Processing: 0.85 quantile, positive r2g:  86%|████████▌ | 1136/1326 [00:28<00:03, 62.91it/s]
# Processing: 0.85 quantile, positive r2g:  86%|████████▋ | 1144/1326 [00:28<00:02, 65.71it/s]
# Processing: 0.85 quantile, positive r2g:  87%|████████▋ | 1151/1326 [00:28<00:03, 55.88it/s]
# Processing: 0.85 quantile, positive r2g:  87%|████████▋ | 1158/1326 [00:28<00:02, 57.00it/s]
# Processing: 0.85 quantile, positive r2g:  88%|████████▊ | 1167/1326 [00:29<00:02, 62.64it/s]
# Processing: 0.85 quantile, positive r2g:  89%|████████▊ | 1174/1326 [00:29<00:02, 58.40it/s]
# Processing: 0.85 quantile, positive r2g:  89%|████████▉ | 1183/1326 [00:29<00:02, 65.91it/s]
# Processing: 0.85 quantile, positive r2g:  90%|████████▉ | 1190/1326 [00:29<00:02, 58.20it/s]
# Processing: 0.85 quantile, positive r2g:  90%|█████████ | 1197/1326 [00:29<00:02, 48.03it/s]
# Processing: 0.85 quantile, positive r2g:  91%|█████████ | 1203/1326 [00:29<00:02, 44.80it/s]
# Processing: 0.85 quantile, positive r2g:  91%|█████████ | 1209/1326 [00:29<00:02, 46.36it/s]
# Processing: 0.85 quantile, positive r2g:  92%|█████████▏| 1214/1326 [00:30<00:02, 46.00it/s]
# Processing: 0.85 quantile, positive r2g:  92%|█████████▏| 1220/1326 [00:30<00:02, 48.82it/s]
# Processing: 0.85 quantile, positive r2g:  92%|█████████▏| 1226/1326 [00:30<00:01, 51.48it/s]
# Processing: 0.85 quantile, positive r2g:  93%|█████████▎| 1232/1326 [00:30<00:01, 52.85it/s]
# Processing: 0.85 quantile, positive r2g:  94%|█████████▎| 1240/1326 [00:30<00:01, 58.22it/s]
# Processing: 0.85 quantile, positive r2g:  94%|█████████▍| 1248/1326 [00:30<00:01, 62.96it/s]
# Processing: 0.85 quantile, positive r2g:  95%|█████████▍| 1255/1326 [00:30<00:01, 62.52it/s]
# Processing: 0.85 quantile, positive r2g:  95%|█████████▌| 1263/1326 [00:30<00:00, 65.39it/s]
# Processing: 0.85 quantile, positive r2g:  96%|█████████▌| 1270/1326 [00:31<00:01, 44.52it/s]
# Processing: 0.85 quantile, positive r2g:  96%|█████████▌| 1276/1326 [00:31<00:01, 43.93it/s]
# Processing: 0.85 quantile, positive r2g:  97%|█████████▋| 1282/1326 [00:31<00:01, 36.08it/s]
# Processing: 0.85 quantile, positive r2g:  97%|█████████▋| 1287/1326 [00:31<00:01, 33.83it/s]
# Processing: 0.85 quantile, positive r2g:  97%|█████████▋| 1292/1326 [00:31<00:00, 36.16it/s]
# Processing: 0.85 quantile, positive r2g:  98%|█████████▊| 1297/1326 [00:31<00:00, 39.04it/s]
# Processing: 0.85 quantile, positive r2g:  98%|█████████▊| 1303/1326 [00:31<00:00, 42.36it/s]
# Processing: 0.85 quantile, positive r2g:  99%|█████████▊| 1308/1326 [00:32<00:00, 43.61it/s]
# Processing: 0.85 quantile, positive r2g:  99%|█████████▉| 1314/1326 [00:32<00:00, 47.37it/s]
# Processing: 0.85 quantile, positive r2g: 100%|█████████▉| 1320/1326 [00:32<00:00, 48.17it/s]
# Processing: 0.85 quantile, positive r2g: 100%|█████████▉| 1325/1326 [00:32<00:00, 42.84it/s]
#  57%|█████▋    | 8/14 [05:04<04:14, 42.35s/it]
# Processing: positive r2g, 0.9 quantile:   0%|          | 0/1326 [00:00<?, ?it/s]
# Processing: positive r2g, 0.9 quantile:   1%|          | 10/1326 [00:00<00:13, 97.00it/s]
# Processing: positive r2g, 0.9 quantile:   2%|▏         | 20/1326 [00:00<00:16, 77.17it/s]
# Processing: positive r2g, 0.9 quantile:   2%|▏         | 29/1326 [00:00<00:15, 81.83it/s]
# Processing: positive r2g, 0.9 quantile:   3%|▎         | 38/1326 [00:00<00:20, 62.03it/s]
# Processing: positive r2g, 0.9 quantile:   3%|▎         | 45/1326 [00:00<00:27, 46.91it/s]
# Processing: positive r2g, 0.9 quantile:   4%|▍         | 51/1326 [00:00<00:27, 45.60it/s]
# Processing: positive r2g, 0.9 quantile:   4%|▍         | 57/1326 [00:01<00:30, 42.05it/s]
# Processing: positive r2g, 0.9 quantile:   5%|▍         | 65/1326 [00:01<00:25, 49.97it/s]
# Processing: positive r2g, 0.9 quantile:   5%|▌         | 71/1326 [00:01<00:31, 39.61it/s]
# Processing: positive r2g, 0.9 quantile:   6%|▌         | 76/1326 [00:01<00:30, 41.51it/s]
# Processing: positive r2g, 0.9 quantile:   6%|▌         | 81/1326 [00:01<00:46, 26.92it/s]
# Processing: positive r2g, 0.9 quantile:   6%|▋         | 85/1326 [00:02<01:02, 19.72it/s]
# Processing: positive r2g, 0.9 quantile:   7%|▋         | 88/1326 [00:02<01:08, 17.97it/s]
# Processing: positive r2g, 0.9 quantile:   7%|▋         | 92/1326 [00:02<00:59, 20.89it/s]
# Processing: positive r2g, 0.9 quantile:   7%|▋         | 95/1326 [00:02<01:03, 19.42it/s]
# Processing: positive r2g, 0.9 quantile:   7%|▋         | 98/1326 [00:03<01:04, 19.02it/s]
# Processing: positive r2g, 0.9 quantile:   8%|▊         | 102/1326 [00:03<00:55, 22.21it/s]
# Processing: positive r2g, 0.9 quantile:   8%|▊         | 106/1326 [00:03<00:48, 25.38it/s]
# Processing: positive r2g, 0.9 quantile:   8%|▊         | 111/1326 [00:03<00:42, 28.33it/s]
# Processing: positive r2g, 0.9 quantile:   9%|▊         | 115/1326 [00:03<00:41, 29.47it/s]
# Processing: positive r2g, 0.9 quantile:  10%|▉         | 126/1326 [00:03<00:25, 47.85it/s]
# Processing: positive r2g, 0.9 quantile:  10%|█         | 137/1326 [00:03<00:19, 61.24it/s]
# Processing: positive r2g, 0.9 quantile:  11%|█         | 148/1326 [00:03<00:15, 73.68it/s]
# Processing: positive r2g, 0.9 quantile:  12%|█▏        | 160/1326 [00:03<00:13, 85.42it/s]
# Processing: positive r2g, 0.9 quantile:  13%|█▎        | 172/1326 [00:04<00:13, 88.19it/s]
# Processing: positive r2g, 0.9 quantile:  14%|█▎        | 182/1326 [00:04<00:19, 60.13it/s]
# Processing: positive r2g, 0.9 quantile:  14%|█▍        | 190/1326 [00:04<00:19, 59.37it/s]
# Processing: positive r2g, 0.9 quantile:  15%|█▍        | 197/1326 [00:04<00:20, 54.95it/s]
# Processing: positive r2g, 0.9 quantile:  15%|█▌        | 204/1326 [00:04<00:19, 56.78it/s]
# Processing: positive r2g, 0.9 quantile:  16%|█▌        | 214/1326 [00:04<00:16, 66.16it/s]
# Processing: positive r2g, 0.9 quantile:  17%|█▋        | 222/1326 [00:04<00:16, 67.28it/s]
# Processing: positive r2g, 0.9 quantile:  17%|█▋        | 232/1326 [00:05<00:14, 74.27it/s]
# Processing: positive r2g, 0.9 quantile:  18%|█▊        | 243/1326 [00:05<00:13, 81.73it/s]
# Processing: positive r2g, 0.9 quantile:  19%|█▉        | 252/1326 [00:05<00:13, 79.62it/s]
# Processing: positive r2g, 0.9 quantile:  20%|█▉        | 261/1326 [00:05<00:13, 80.30it/s]
# Processing: positive r2g, 0.9 quantile:  21%|██        | 272/1326 [00:05<00:12, 87.59it/s]
# Processing: positive r2g, 0.9 quantile:  21%|██        | 281/1326 [00:05<00:14, 72.89it/s]
# Processing: positive r2g, 0.9 quantile:  22%|██▏       | 289/1326 [00:05<00:16, 64.33it/s]
# Processing: positive r2g, 0.9 quantile:  22%|██▏       | 296/1326 [00:05<00:17, 59.14it/s]
# Processing: positive r2g, 0.9 quantile:  23%|██▎       | 303/1326 [00:06<00:17, 60.09it/s]
# Processing: positive r2g, 0.9 quantile:  23%|██▎       | 311/1326 [00:06<00:16, 63.31it/s]
# Processing: positive r2g, 0.9 quantile:  24%|██▍       | 319/1326 [00:06<00:15, 66.51it/s]
# Processing: positive r2g, 0.9 quantile:  25%|██▍       | 326/1326 [00:06<00:16, 60.02it/s]
# Processing: positive r2g, 0.9 quantile:  25%|██▌       | 333/1326 [00:06<00:18, 54.06it/s]
# Processing: positive r2g, 0.9 quantile:  26%|██▌       | 339/1326 [00:06<00:18, 52.34it/s]
# Processing: positive r2g, 0.9 quantile:  26%|██▌       | 345/1326 [00:06<00:19, 50.44it/s]
# ...
# Processing: BASC binarized, positive r2g:  49%|████▉     | 655/1326 [00:17<00:20, 33.10it/s]
# Processing: BASC binarized, positive r2g:  50%|████▉     | 661/1326 [00:17<00:16, 39.30it/s]
# Processing: BASC binarized, positive r2g:  50%|█████     | 666/1326 [00:17<00:15, 41.72it/s]
# Processing: BASC binarized, positive r2g:  51%|█████     | 671/1326 [00:17<00:15, 42.81it/s]
# Processing: BASC binarized, positive r2g:  51%|█████     | 676/1326 [00:17<00:14, 44.28it/s]
# Processing: BASC binarized, positive r2g:  51%|█████▏    | 682/1326 [00:17<00:13, 47.09it/s]
# Processing: BASC binarized, positive r2g:  52%|█████▏    | 689/1326 [00:17<00:12, 52.40it/s]
# Processing: BASC binarized, positive r2g:  52%|█████▏    | 696/1326 [00:18<00:11, 57.08it/s]
# Processing: BASC binarized, positive r2g:  53%|█████▎    | 704/1326 [00:18<00:09, 62.24it/s]
# Processing: BASC binarized, positive r2g:  54%|█████▎    | 712/1326 [00:18<00:09, 64.86it/s]
# Processing: BASC binarized, positive r2g:  54%|█████▍    | 720/1326 [00:18<00:08, 68.97it/s]
# Processing: BASC binarized, positive r2g:  55%|█████▍    | 729/1326 [00:18<00:08, 74.48it/s]
# Processing: BASC binarized, positive r2g:  56%|█████▌    | 738/1326 [00:18<00:07, 77.89it/s]
# Processing: BASC binarized, positive r2g:  56%|█████▋    | 747/1326 [00:18<00:08, 71.61it/s]
# Processing: BASC binarized, positive r2g:  57%|█████▋    | 755/1326 [00:18<00:09, 59.15it/s]
# Processing: BASC binarized, positive r2g:  57%|█████▋    | 762/1326 [00:19<00:12, 45.55it/s]
# Processing: BASC binarized, positive r2g:  58%|█████▊    | 769/1326 [00:19<00:11, 49.12it/s]
# Processing: BASC binarized, positive r2g:  58%|█████▊    | 775/1326 [00:19<00:12, 44.25it/s]
# Processing: BASC binarized, positive r2g:  59%|█████▉    | 780/1326 [00:19<00:16, 33.12it/s]
# Processing: BASC binarized, positive r2g:  59%|█████▉    | 784/1326 [00:20<00:21, 25.60it/s]
# Processing: BASC binarized, positive r2g:  59%|█████▉    | 788/1326 [00:20<00:24, 21.93it/s]
# Processing: BASC binarized, positive r2g:  60%|█████▉    | 791/1326 [00:20<00:23, 22.62it/s]
# Processing: BASC binarized, positive r2g:  60%|██████    | 797/1326 [00:20<00:18, 29.13it/s]
# Processing: BASC binarized, positive r2g:  61%|██████    | 803/1326 [00:20<00:15, 34.72it/s]
# Processing: BASC binarized, positive r2g:  61%|██████    | 808/1326 [00:20<00:14, 36.29it/s]
# Processing: BASC binarized, positive r2g:  61%|██████▏   | 813/1326 [00:20<00:14, 35.81it/s]
# Processing: BASC binarized, positive r2g:  62%|██████▏   | 818/1326 [00:21<00:13, 38.21it/s]
# Processing: BASC binarized, positive r2g:  62%|██████▏   | 824/1326 [00:21<00:11, 42.88it/s]
# Processing: BASC binarized, positive r2g:  63%|██████▎   | 833/1326 [00:21<00:09, 53.23it/s]
# Processing: BASC binarized, positive r2g:  63%|██████▎   | 841/1326 [00:21<00:08, 59.70it/s]
# Processing: BASC binarized, positive r2g:  64%|██████▍   | 848/1326 [00:21<00:08, 59.49it/s]
# Processing: BASC binarized, positive r2g:  64%|██████▍   | 855/1326 [00:21<00:07, 61.89it/s]
# Processing: BASC binarized, positive r2g:  65%|██████▌   | 862/1326 [00:21<00:07, 62.57it/s]
# Processing: BASC binarized, positive r2g:  66%|██████▌   | 869/1326 [00:21<00:07, 60.32it/s]
# Processing: BASC binarized, positive r2g:  66%|██████▌   | 876/1326 [00:21<00:07, 56.61it/s]
# Processing: BASC binarized, positive r2g:  67%|██████▋   | 883/1326 [00:22<00:07, 59.25it/s]
# Processing: BASC binarized, positive r2g:  67%|██████▋   | 890/1326 [00:22<00:07, 60.53it/s]
# Processing: BASC binarized, positive r2g:  68%|██████▊   | 897/1326 [00:22<00:07, 61.09it/s]
# Processing: BASC binarized, positive r2g:  68%|██████▊   | 906/1326 [00:22<00:06, 68.52it/s]
# Processing: BASC binarized, positive r2g:  69%|██████▉   | 913/1326 [00:22<00:06, 67.29it/s]
# Processing: BASC binarized, positive r2g:  69%|██████▉   | 920/1326 [00:22<00:06, 64.04it/s]
# Processing: BASC binarized, positive r2g:  70%|██████▉   | 928/1326 [00:22<00:05, 66.96it/s]
# Processing: BASC binarized, positive r2g:  71%|███████   | 936/1326 [00:22<00:05, 68.78it/s]
# Processing: BASC binarized, positive r2g:  71%|███████   | 943/1326 [00:22<00:05, 67.21it/s]
# Processing: BASC binarized, positive r2g:  72%|███████▏  | 952/1326 [00:23<00:05, 71.89it/s]
# Processing: BASC binarized, positive r2g:  72%|███████▏  | 960/1326 [00:23<00:05, 70.96it/s]
# Processing: BASC binarized, positive r2g:  73%|███████▎  | 968/1326 [00:23<00:04, 72.96it/s]
# Processing: BASC binarized, positive r2g:  74%|███████▎  | 977/1326 [00:23<00:04, 71.89it/s]
# Processing: BASC binarized, positive r2g:  74%|███████▍  | 985/1326 [00:23<00:04, 73.92it/s]
# Processing: BASC binarized, positive r2g:  75%|███████▍  | 993/1326 [00:23<00:05, 63.21it/s]
# Processing: BASC binarized, positive r2g:  75%|███████▌  | 1000/1326 [00:23<00:05, 62.76it/s]
# Processing: BASC binarized, positive r2g:  76%|███████▌  | 1008/1326 [00:23<00:04, 66.58it/s]
# Processing: BASC binarized, positive r2g:  77%|███████▋  | 1016/1326 [00:24<00:05, 61.83it/s]
# Processing: BASC binarized, positive r2g:  77%|███████▋  | 1024/1326 [00:24<00:04, 64.71it/s]
# Processing: BASC binarized, positive r2g:  78%|███████▊  | 1032/1326 [00:24<00:04, 67.51it/s]
# Processing: BASC binarized, positive r2g:  78%|███████▊  | 1039/1326 [00:24<00:04, 66.72it/s]
# Processing: BASC binarized, positive r2g:  79%|███████▉  | 1046/1326 [00:24<00:04, 66.79it/s]
# Processing: BASC binarized, positive r2g:  79%|███████▉  | 1053/1326 [00:24<00:04, 65.13it/s]
# Processing: BASC binarized, positive r2g:  80%|████████  | 1061/1326 [00:24<00:03, 68.38it/s]
# Processing: BASC binarized, positive r2g:  81%|████████  | 1068/1326 [00:24<00:05, 48.91it/s]
# Processing: BASC binarized, positive r2g:  81%|████████  | 1074/1326 [00:25<00:06, 37.01it/s]
# Processing: BASC binarized, positive r2g:  81%|████████▏ | 1079/1326 [00:25<00:06, 38.86it/s]
# Processing: BASC binarized, positive r2g:  82%|████████▏ | 1084/1326 [00:25<00:06, 35.86it/s]
# Processing: BASC binarized, positive r2g:  82%|████████▏ | 1089/1326 [00:25<00:06, 36.07it/s]
# Processing: BASC binarized, positive r2g:  83%|████████▎ | 1095/1326 [00:25<00:05, 41.02it/s]
# Processing: BASC binarized, positive r2g:  83%|████████▎ | 1102/1326 [00:25<00:04, 45.60it/s]
# Processing: BASC binarized, positive r2g:  83%|████████▎ | 1107/1326 [00:26<00:06, 35.79it/s]
# Processing: BASC binarized, positive r2g:  84%|████████▍ | 1112/1326 [00:26<00:06, 31.88it/s]
# Processing: BASC binarized, positive r2g:  84%|████████▍ | 1116/1326 [00:26<00:06, 31.90it/s]
# Processing: BASC binarized, positive r2g:  85%|████████▍ | 1122/1326 [00:26<00:05, 37.69it/s]
# Processing: BASC binarized, positive r2g:  85%|████████▍ | 1127/1326 [00:26<00:05, 38.30it/s]
# Processing: BASC binarized, positive r2g:  85%|████████▌ | 1132/1326 [00:26<00:05, 37.07it/s]
# Processing: BASC binarized, positive r2g:  86%|████████▌ | 1136/1326 [00:26<00:05, 36.04it/s]
# Processing: BASC binarized, positive r2g:  86%|████████▌ | 1140/1326 [00:26<00:05, 35.65it/s]
# Processing: BASC binarized, positive r2g:  86%|████████▋ | 1144/1326 [00:27<00:05, 32.74it/s]
# Processing: BASC binarized, positive r2g:  87%|████████▋ | 1148/1326 [00:27<00:06, 28.08it/s]
# Processing: BASC binarized, positive r2g:  87%|████████▋ | 1151/1326 [00:27<00:07, 24.83it/s]
# Processing: BASC binarized, positive r2g:  87%|████████▋ | 1155/1326 [00:27<00:06, 26.04it/s]
# Processing: BASC binarized, positive r2g:  87%|████████▋ | 1158/1326 [00:27<00:06, 25.71it/s]
# Processing: BASC binarized, positive r2g:  88%|████████▊ | 1162/1326 [00:27<00:06, 27.32it/s]
# Processing: BASC binarized, positive r2g:  88%|████████▊ | 1167/1326 [00:28<00:05, 29.74it/s]
# Processing: BASC binarized, positive r2g:  88%|████████▊ | 1171/1326 [00:28<00:06, 25.05it/s]
# Processing: BASC binarized, positive r2g:  89%|████████▊ | 1175/1326 [00:28<00:05, 27.45it/s]
# Processing: BASC binarized, positive r2g:  89%|████████▉ | 1180/1326 [00:28<00:04, 31.87it/s]
# Processing: BASC binarized, positive r2g:  89%|████████▉ | 1185/1326 [00:28<00:04, 35.05it/s]
# Processing: BASC binarized, positive r2g:  90%|████████▉ | 1190/1326 [00:28<00:03, 37.23it/s]
# Processing: BASC binarized, positive r2g:  90%|█████████ | 1194/1326 [00:28<00:03, 36.92it/s]
# Processing: BASC binarized, positive r2g:  90%|█████████ | 1198/1326 [00:28<00:03, 32.80it/s]
# Processing: BASC binarized, positive r2g:  91%|█████████ | 1202/1326 [00:29<00:03, 32.93it/s]
# Processing: BASC binarized, positive r2g:  91%|█████████ | 1206/1326 [00:29<00:03, 31.65it/s]
# Processing: BASC binarized, positive r2g:  91%|█████████▏| 1210/1326 [00:29<00:03, 33.34it/s]
# Processing: BASC binarized, positive r2g:  92%|█████████▏| 1214/1326 [00:29<00:03, 30.84it/s]
# Processing: BASC binarized, positive r2g:  92%|█████████▏| 1218/1326 [00:29<00:03, 32.72it/s]
# Processing: BASC binarized, positive r2g:  92%|█████████▏| 1222/1326 [00:29<00:03, 31.63it/s]
# Processing: BASC binarized, positive r2g:  93%|█████████▎| 1227/1326 [00:29<00:02, 34.09it/s]
# Processing: BASC binarized, positive r2g:  93%|█████████▎| 1231/1326 [00:29<00:02, 34.08it/s]
# Processing: BASC binarized, positive r2g:  93%|█████████▎| 1235/1326 [00:30<00:02, 34.81it/s]
# Processing: BASC binarized, positive r2g:  93%|█████████▎| 1239/1326 [00:30<00:02, 32.60it/s]
# Processing: BASC binarized, positive r2g:  94%|█████████▎| 1243/1326 [00:30<00:02, 30.80it/s]
# Processing: BASC binarized, positive r2g:  94%|█████████▍| 1247/1326 [00:30<00:02, 32.91it/s]
# Processing: BASC binarized, positive r2g:  94%|█████████▍| 1251/1326 [00:30<00:02, 33.07it/s]
# Processing: BASC binarized, positive r2g:  95%|█████████▍| 1255/1326 [00:30<00:02, 31.60it/s]
# Processing: BASC binarized, positive r2g:  95%|█████████▍| 1259/1326 [00:30<00:02, 29.89it/s]
# Processing: BASC binarized, positive r2g:  95%|█████████▌| 1264/1326 [00:30<00:01, 33.83it/s]
# Processing: BASC binarized, positive r2g:  96%|█████████▌| 1268/1326 [00:31<00:02, 27.85it/s]
# Processing: BASC binarized, positive r2g:  96%|█████████▌| 1274/1326 [00:31<00:01, 33.06it/s]
# Processing: BASC binarized, positive r2g:  96%|█████████▋| 1278/1326 [00:31<00:01, 32.01it/s]
# Processing: BASC binarized, positive r2g:  97%|█████████▋| 1282/1326 [00:31<00:01, 29.48it/s]
# Processing: BASC binarized, positive r2g:  97%|█████████▋| 1286/1326 [00:31<00:01, 27.87it/s]
# Processing: BASC binarized, positive r2g:  97%|█████████▋| 1291/1326 [00:31<00:01, 31.38it/s]
# Processing: BASC binarized, positive r2g:  98%|█████████▊| 1296/1326 [00:32<00:00, 35.03it/s]
# Processing: BASC binarized, positive r2g:  98%|█████████▊| 1300/1326 [00:32<00:00, 31.71it/s]
# Processing: BASC binarized, positive r2g:  98%|█████████▊| 1304/1326 [00:32<00:00, 30.35it/s]
# Processing: BASC binarized, positive r2g:  99%|█████████▊| 1308/1326 [00:32<00:00, 31.34it/s]
# Processing: BASC binarized, positive r2g:  99%|█████████▉| 1312/1326 [00:32<00:00, 31.07it/s]
# Processing: BASC binarized, positive r2g:  99%|█████████▉| 1316/1326 [00:32<00:00, 31.88it/s]
# Processing: BASC binarized, positive r2g: 100%|█████████▉| 1320/1326 [00:32<00:00, 30.91it/s]
# Processing: BASC binarized, positive r2g: 100%|█████████▉| 1324/1326 [00:32<00:00, 29.35it/s]
# 100%|██████████| 14/14 [08:57<00:00, 38.43s/it]
# 2022-12-23 17:20:50,743 GSEA         INFO     Subsetting TF2G adjacencies for TF with motif.
# 2022-12-23 17:20:59,833	INFO worker.py:1529 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8266
# 2022-12-23 17:21:01,679 GSEA         INFO     Running GSEA...
# initializing:   2%|▏         | 426/17869 [01:38<1:12:27,  4.01it/s](_ray_run_gsea_for_e_module pid=15319) /rugpfs/fs0/home/amillet/miniconda3/envs/scenicplus/lib/python3.8/site-packages/gseapy/algorithm.py:72: RuntimeWarning: divide by zero encountered in divide
# (_ray_run_gsea_for_e_module pid=15319)   norm_no_tag = 1.0/Nmiss
# (_ray_run_gsea_for_e_module pid=15319) /rugpfs/fs0/home/amillet/miniconda3/envs/scenicplus/lib/python3.8/site-packages/gseapy/algorithm.py:74: RuntimeWarning: invalid value encountered in multiply
# (_ray_run_gsea_for_e_module pid=15319)   RES = np.cumsum(tag_indicator * correl_vector * norm_tag - no_tag_indicator * norm_no_tag, axis=axis)
# initializing: 100%|██████████| 17869/17869 [05:29<00:00, 54.20it/s]
# Running using 12 cores: 100%|██████████| 10726/10726 [00:58<00:00, 184.81it/s]
# 2022-12-23 17:27:32,113 GSEA         INFO     Subsetting on adjusted pvalue: 1, minimal NES: 0 and minimal leading edge genes 10
# 2022-12-23 17:27:33,672 GSEA         INFO     Merging eRegulons
# 2022-12-23 17:27:34,012 GSEA         INFO     Storing eRegulons in .uns[eRegulons].
# 2022-12-23 17:27:37,653 SCENIC+_wrapper INFO     Formatting eGRNs
# 2022-12-23 17:30:38,524 SCENIC+_wrapper INFO     Converting eGRNs to signatures
# 2022-12-23 17:30:43,468 SCENIC+_wrapper INFO     Calculating eGRNs AUC
# 2022-12-23 17:30:43,469 SCENIC+_wrapper INFO     Calculating region ranking
# 2022-12-23 17:32:36,796 SCENIC+_wrapper INFO     Calculating eGRNs region based AUC
# 2022-12-23 17:32:53,046 SCENIC+_wrapper INFO     Calculating gene ranking
# 2022-12-23 17:33:00,173 SCENIC+_wrapper INFO     Calculating eGRNs gene based AUC
# 2022-12-23 17:33:10,871 SCENIC+_wrapper INFO     Calculating TF-eGRNs AUC correlation
# 2022-12-23 17:33:26,591 SCENIC+_wrapper INFO     Binarizing eGRNs AUC
# 2022-12-23 17:39:52,798 SCENIC+_wrapper INFO     Making eGRNs AUC UMAP
# 2022-12-23 17:40:21,988 SCENIC+_wrapper INFO     Making eGRNs AUC tSNE
# 2022-12-23 17:40:54,182 SCENIC+_wrapper INFO     Calculating eRSS
# 2022-12-23 17:41:02,641 SCENIC+_wrapper INFO     Calculating DEGs/DARs
# 2022-12-23 17:41:02,643 SCENIC+      INFO     Calculating DEGs for variable GEX_celltype
# 2022-12-23 17:41:08,947 SCENIC+      INFO     There are 2747 variable features
# ... storing 'ACC_celltype' as categorical
# ... storing 'ACC_sample_id' as categorical
# 2022-12-23 17:41:12,742 SCENIC+      INFO     Finished calculating DEGs for variable GEX_celltype
# 2022-12-23 17:41:12,744 SCENIC+      INFO     Calculating DARs for variable GEX_celltype
# 2022-12-23 17:41:53,013 SCENIC+      INFO     There are 41955 variable features
# ... storing 'ACC_celltype' as categorical
# ... storing 'ACC_sample_id' as categorical
# 2022-12-23 17:42:34,818 SCENIC+      INFO     Finished calculating DARs for variable GEX_celltype
# 2022-12-23 17:42:34,822 SCENIC+_wrapper INFO     Exporting to loom file
# 2022-12-23 17:42:34,823 SCENIC+      INFO     Formatting data
# 2022-12-23 17:42:37,812 SCENIC+      INFO     Creating minimal loom
# 2022-12-23 17:42:48,901 SCENIC+      INFO     Adding annotations
# 2022-12-23 17:42:50,442 SCENIC+      INFO     Adding clusterings
# 2022-12-23 17:42:50,497 SCENIC+      INFO     Adding markers
# 2022-12-23 17:42:50,767 SCENIC+      INFO     Exporting
# 2022-12-23 17:42:55,394 SCENIC+      INFO     Formatting data
# 2022-12-23 17:43:28,258 SCENIC+      INFO     Creating minimal loom
# 2022-12-23 17:45:32,777 SCENIC+      INFO     Adding annotations
# 2022-12-23 17:45:50,763 SCENIC+      INFO     Adding clusterings
# 2022-12-23 17:45:50,862 SCENIC+      INFO     Adding markers
# 2022-12-23 17:45:54,601 SCENIC+      INFO     Exporting
# 2022-12-23 17:46:58,177 SCENIC+_wrapper INFO     Exporting to UCSC
# 2022-12-23 17:46:58,642 R2G          INFO     Downloading gene annotation from biomart, using dataset: mmusculus_gene_ensembl
# 2022-12-23 17:47:07,439 R2G          INFO     Formatting data ...
# 2022-12-23 17:47:24,716 R2G          INFO     Writing data to: E4AD_1yr/scenicplus/r2g.rho.bed
# 2022-12-23 17:47:25,695 R2G          INFO     Writing data to: E4AD_1yr/scenicplus/r2g.rho.bb
# 2022-12-23 17:47:29,708 R2G          INFO     Downloading gene annotation from biomart, using dataset: mmusculus_gene_ensembl
# 2022-12-23 17:47:30,265 R2G          INFO     Formatting data ...
# 2022-12-23 17:47:46,946 R2G          INFO     Writing data to: E4AD_1yr/scenicplus/r2g.importance.bed
# 2022-12-23 17:47:47,385 R2G          INFO     Writing data to: E4AD_1yr/scenicplus/r2g.importance.bb
# 2022-12-23 17:47:52,582 SCENIC+_wrapper INFO     Saving object
# 2022-12-23 18:03:30,229 SCENIC+_wrapper INFO     Finished! Took 116.60989734729131 minutes

# %% [markdown]
# Note: for this code to run, had to edit `src/scenicplus/loom.py` line 174 from `), columns=cv.get_feature_names(), index=regulons.keys())` to `), columns=cv.get_feature_names_out(), index=regulons.keys())` due to an update in scikit-learn. See: https://github.com/aertslab/scenicplus/issues/76

# %%
scplus_obj

# %% [markdown]
# ## FINALLY time to explore the data!

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import sys
import os
_stderr = sys.stderr
null = open(os.devnull,'wb')

# %%
import dill
scplus_obj = dill.load(open('E4AD_1yr/scenicplus/scplus_obj.pkl', 'rb'))

# %%
from scenicplus.preprocessing.filtering import apply_std_filtering_to_eRegulons
apply_std_filtering_to_eRegulons(scplus_obj)

# %%
work_dir = "E4AD_1yr"
from scenicplus.eregulon_enrichment import score_eRegulons
region_ranking = dill.load(open(os.path.join(work_dir, 'scenicplus/region_ranking.pkl'), 'rb')) #load ranking calculated using the wrapper function
gene_ranking = dill.load(open(os.path.join(work_dir, 'scenicplus/gene_ranking.pkl'), 'rb')) #load ranking calculated using the wrapper function
score_eRegulons(scplus_obj,
                ranking = region_ranking,
                eRegulon_signatures_key = 'eRegulon_signatures_filtered',
                key_added = 'eRegulon_AUC_filtered',
                enrichment_type= 'region',
                auc_threshold = 0.05,
                normalize = False,
                n_cpu = 5)
score_eRegulons(scplus_obj,
                gene_ranking,
                eRegulon_signatures_key = 'eRegulon_signatures_filtered',
                key_added = 'eRegulon_AUC_filtered',
                enrichment_type = 'gene',
                auc_threshold = 0.05,
                normalize= False,
                n_cpu = 5)

# %%
from scenicplus.dimensionality_reduction import run_eRegulons_tsne, run_eRegulons_umap
run_eRegulons_umap(
    scplus_obj = scplus_obj,
    auc_key = 'eRegulon_AUC_filtered',
    reduction_name = 'eRegulons_UMAP', #overwrite previously calculated UMAP
)
run_eRegulons_tsne(
    scplus_obj = scplus_obj,
    auc_key = 'eRegulon_AUC_filtered',
    reduction_name = 'eRegulons_tSNE', #overwrite previously calculated tSNE
)

# %%
scplus_obj.metadata_cell['GEX_celltype'].value_counts()

# %%
from scenicplus.dimensionality_reduction import plot_metadata_given_ax
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

#specify color_dictionary

color_dict = {
    'Homeostatic Microglia': "#065143",
    'Selplg-lo Microglia': "#70B77E",
    'mt-Enriched Microglia': "#E0A890",
    'mt-Depleted Microglia': "#053C5E",
    'DAM-1': "#F56476",
    'DAM-2': "#CE1483" ,
    'TIMs': "#38A3A5",
    'Siglech-hi Microglia': "#80ED99"
}

fig, axs = plt.subplots(ncols=2, figsize = (16, 8))
plot_metadata_given_ax(
    scplus_obj=scplus_obj,
    ax = axs[0],
    reduction_name = 'eRegulons_UMAP',
    variable = 'GEX_celltype', #note the GEX_ prefix, this metadata originated from the gene expression metadata (on which we did the cell type annotation before)
    color_dictionary={'GEX_celltype': color_dict}
)
plot_metadata_given_ax(
    scplus_obj=scplus_obj,
    ax = axs[1],
    reduction_name = 'eRegulons_tSNE',
    variable = 'GEX_celltype', #note the GEX_ prefix, this metadata originated from the gene expression metadata (on which we did the cell type annotation before)
    color_dictionary={'GEX_celltype': color_dict}
)
fig.tight_layout()
sns.despine(ax = axs[0]) #remove top and right edge of axis border
sns.despine(ax = axs[1]) #remove top and right edge of axis border
plt.show()

# %%
from scenicplus.dimensionality_reduction import plot_eRegulon
plot_eRegulon(
    scplus_obj = scplus_obj,
    reduction_name = 'eRegulons_UMAP',
    selected_regulons = ['Fos_+', 'Jun_+', 'Fosb_+', 'Klf4_+', 'Egr3_+'],
    scale = True,
    auc_key = 'eRegulon_AUC_filtered')

# %%
df = scplus_obj.uns['eRegulon_metadata_filtered']
df[df.TF == "Jun"]

# %%
from scenicplus.dimensionality_reduction import plot_AUC_given_ax

fig, ax = plt.subplots(figsize = (8,8))
plot_AUC_given_ax(
    scplus_obj = scplus_obj,
    reduction_name = 'eRegulons_tSNE',
    feature = 'Jun_+_(73g)',
    ax = ax,
    auc_key = 'eRegulon_AUC_filtered',
    signature_key = 'Gene_based')
sns.despine(ax = ax)
plt.show()

# %%
from scenicplus.cistromes import TF_cistrome_correlation, generate_pseudobulks

generate_pseudobulks(
        scplus_obj = scplus_obj,
        variable = 'GEX_celltype',
        auc_key = 'eRegulon_AUC_filtered',
        signature_key = 'Gene_based')
generate_pseudobulks(
        scplus_obj = scplus_obj,
        variable = 'GEX_celltype',
        auc_key = 'eRegulon_AUC_filtered',
        signature_key = 'Region_based')

TF_cistrome_correlation(
            scplus_obj,
            use_pseudobulk = True,
            variable = 'GEX_celltype',
            auc_key = 'eRegulon_AUC_filtered',
            signature_key = 'Gene_based',
            out_key = 'filtered_gene_based')
TF_cistrome_correlation(
            scplus_obj,
            use_pseudobulk = True,
            variable = 'GEX_celltype',
            auc_key = 'eRegulon_AUC_filtered',
            signature_key = 'Region_based',
            out_key = 'filtered_region_based')

# %%
scplus_obj.uns['TF_cistrome_correlation']['filtered_region_based'].head()

# %%
import numpy as np
n_targets = [int(x.split('(')[1].replace('r)', '')) for x in scplus_obj.uns['TF_cistrome_correlation']['filtered_region_based']['Cistrome']]
rho = scplus_obj.uns['TF_cistrome_correlation']['filtered_region_based']['Rho'].to_list()
adj_pval = scplus_obj.uns['TF_cistrome_correlation']['filtered_region_based']['Adjusted_p-value'].to_list()

thresholds = {
        'rho': [-0.15, 0.15],
        'n_targets': 0
}
import seaborn as sns
fig, ax = plt.subplots(figsize = (10, 5))
sc = ax.scatter(rho, n_targets, c = -np.log10(adj_pval), s = 5)
ax.set_xlabel('Correlation coefficient')
ax.set_ylabel('nr. target regions')
#ax.hlines(y = thresholds['n_targets'], xmin = min(rho), xmax = max(rho), color = 'black', ls = 'dashed', lw = 1)
ax.vlines(x = thresholds['rho'], ymin = 0, ymax = max(n_targets), color = 'black', ls = 'dashed', lw = 1)
ax.text(x = thresholds['rho'][0], y = max(n_targets), s = str(thresholds['rho'][0]))
ax.text(x = thresholds['rho'][1], y = max(n_targets), s = str(thresholds['rho'][1]))
sns.despine(ax = ax)
fig.colorbar(sc, label = '-log10(adjusted_pvalue)', ax = ax)
plt.show()

# %%
selected_cistromes = scplus_obj.uns['TF_cistrome_correlation']['filtered_region_based'].loc[
        np.logical_or(
                scplus_obj.uns['TF_cistrome_correlation']['filtered_region_based']['Rho'] > thresholds['rho'][1],
                scplus_obj.uns['TF_cistrome_correlation']['filtered_region_based']['Rho'] < thresholds['rho'][0]
        )]['Cistrome'].to_list()
selected_eRegulons = [x.split('_(')[0] for x in selected_cistromes]
selected_eRegulons_gene_sig = [
        x for x in scplus_obj.uns['eRegulon_signatures_filtered']['Gene_based'].keys()
        if x.split('_(')[0] in selected_eRegulons]
selected_eRegulons_region_sig = [
        x for x in scplus_obj.uns['eRegulon_signatures_filtered']['Region_based'].keys()
        if x.split('_(')[0] in selected_eRegulons]
#save the results in the scenicplus object
scplus_obj.uns['selected_eRegulon'] = {'Gene_based': selected_eRegulons_gene_sig, 'Region_based': selected_eRegulons_region_sig}
print(f'selected: {len(selected_eRegulons_gene_sig)} eRegulons')

# %%
dill.dump(scplus_obj, open(os.path.join(work_dir, 'scenicplus/scplus_obj.pkl'), 'wb'), protocol=-1)

# %%
from scenicplus.plotting.dotplot import heatmap_dotplot
heatmap_dotplot(
        scplus_obj = scplus_obj,
        size_matrix = scplus_obj.uns['eRegulon_AUC_filtered']['Region_based'], #specify what to plot as dot sizes, target region enrichment in this case
        color_matrix = scplus_obj.to_df('EXP'), #specify  what to plot as colors, TF expression in this case
        scale_size_matrix = True,
        scale_color_matrix = True,
        group_variable = 'GEX_celltype',
        subset_eRegulons = scplus_obj.uns['selected_eRegulon']['Gene_based'],
        index_order = ['Homeostatic Microglia', 'Selplg-lo Microglia', 'mt-Enriched Microglia', 'mt-Depleted Microglia', 'DAM-1', 'DAM-2', 'TIMs', 'Siglech-hi Microglia'],
        figsize = (15, 20),
        orientation = 'vertical',
        split_repressor_activator = False,
        save = "eregulon_dotplot.png") # set to False since we get no repressors :hehe:

# %%
from scenicplus.plotting.dotplot import generate_dotplot_df
df = generate_dotplot_df(scplus_obj = scplus_obj,
        size_matrix = scplus_obj.uns['eRegulon_AUC_filtered']['Region_based'], #specify what to plot as dot sizes, target region enrichment in this case
        color_matrix = scplus_obj.to_df('EXP'), #specify  what to plot as colors, TF expression in this case
        scale_size_matrix = True,
        scale_color_matrix = True,
        group_variable = 'GEX_celltype',
        subset_eRegulons = scplus_obj.uns['selected_eRegulon']['Gene_based'],)

# %%
index_order = ['Homeostatic Microglia', 'Selplg-lo Microglia', 'mt-Enriched Microglia', 'mt-Depleted Microglia', 'DAM-1', 'DAM-2', 'TIMs', 'Siglech-hi Microglia']
tmp = df[['index', 'eRegulon_name', 'color_val']
        ].pivot_table(index = 'index', columns = 'eRegulon_name'
        ).fillna(0)['color_val']
tmp = tmp.loc[index_order]
idx_max = tmp.idxmax(axis = 0)
order = pd.concat([idx_max[idx_max == x] for x in tmp.index.tolist() if len(df[df == x]) > 0]).index.tolist()

# %%
df.to_csv("eregulons_df.csv")
pd.DataFrame(order).to_csv("regulon_order.csv")

# %%
from scenicplus.RSS import *
regulon_specificity_scores(
        scplus_obj,
        variable = 'GEX_celltype',
        auc_key = 'eRegulon_AUC_filtered',
        signature_keys = ['Region_based'],
        selected_regulons = [x for x in scplus_obj.uns['selected_eRegulon']['Region_based'] if '-' not in x],
        out_key_suffix = '_filtered')

# %%
plot_rss(scplus_obj, 'GEX_celltype_filtered', num_columns=2, top_n=10, figsize = (10, 20))

# %%
flat_list = lambda t: [item for sublist in t for item in sublist]
selected_markers = list(set(flat_list(
    [scplus_obj.uns['RSS']['GEX_celltype_filtered'].loc[celltype].sort_values(ascending = False).head(10).index.to_list()
    for celltype in scplus_obj.uns['RSS']['GEX_celltype_filtered'].index])))

# %%
from scenicplus.plotting.correlation_plot import *

region_intersetc_data, Z = jaccard_heatmap(
        scplus_obj,
        method = 'intersect',
        gene_or_region_based = 'Region_based',
        use_plotly = False,
        selected_regulons = selected_markers,
        signature_key = 'eRegulon_signatures_filtered',
        figsize = (10, 10), return_data = True, vmax = 0.5, cmap = 'plasma')

# %% [markdown]
# ## Perturbation simulation

# %%
from scenicplus.dimensionality_reduction import run_eRegulons_pca
run_eRegulons_pca(
        scplus_obj,
        auc_key = 'eRegulon_AUC_filtered',
        reduction_name = 'eRegulons_PCA_gene_based',
        selected_regulons = scplus_obj.uns['selected_eRegulon']['Gene_based'])

# %%
from pycisTopic.diff_features import find_highly_variable_features
hvg = find_highly_variable_features(scplus_obj.to_df('EXP')[list(set(scplus_obj.uns['eRegulon_metadata_filtered']['Gene']))].T, n_top_features = 200, plot = False)

# %%
mapping = {"Homeostatic Microglia":"Homeostatic Microglia",
          "Selplg-lo Microglia":"Homeostatic Microglia",
          "DAM-2":"DAMs",
          "mt-Enriched Microglia":"Homeostatic Microglia",
          "TIMs":"TIMs",
          "Siglech-hi Microglia":"Homeostatic Microglia",
          "mt-Depleted Microglia":"Homeostatic Microglia",
          "DAM-1":"DAMs"}
scplus_obj.metadata_cell['summarized_celltype'] = scplus_obj.metadata_cell['GEX_celltype'].map(mapping)
mapping_color_dict = {
    'Homeostatic Microglia': "#1ebd70",
    'DAMs': "#CE1483" ,
    'TIMs': "#e0a038",
}

# %%
from typing import Optional
from typing import List
import logging
def plot_perturbation_effect_in_embedding_custom(
    scplus_obj: 'SCENICPLUS', 
    reduction_name: str, 
    variable: str,
    calculate_perturbed_auc_values: bool = True,
    AUC_key: str = 'eRegulon_AUC',
    perturbed_matrix: pd.DataFrame = None, 
    perturbation: dict = None, 
    eRegulon_metadata_key: Optional[str] = 'eRegulon_metadata',
    eRegulon_signatures_key: str = 'eRegulon_signatures',
    n_iter: Optional[int] = 5, 
    regressors: Optional[dict] = None, 
    genes_to_use: Optional[List] = None, 
    regressor_type: Optional[str] = 'GBM',
    regressor_kwargs: Optional[dict] = None, 
    eRegulons_to_use: Optional[List] = None, 
    grid_offset_frac: Optional[float] = 0.005,
    grid_n_cols: Optional[int] = 25,
    grid_n_rows: Optional[int] = 25,
    grid_n_neighbors: Optional[int] = 25,
    n_cpu: Optional[int] = 1,
    figsize: Optional[tuple] = (6.4, 4.8),
    save: Optional[str] = None,
    density: Optional[float] = 3,
    arrow_width: Optional[float] = 0.5,
    arrowsize: Optional[float] = 1,
    **kwargs):
    """
    Plot dimensionality reduction with perturbation arrows in a grid.

    Parameters
    ----------
    scplus_obj: `class::SCENICPLUS`
        A SCENICPLUS object.
    reduction_name: str
        Name of the dimensionality reduction on which to plot the perturbation effect.
        Should be included in scplus_obj.dr.keys()
    variable: str
        Categorical variable by which to color cells by.
    calculate_perturbed_auc_values: bool, optional
        Specify wether eRegulon AUC values should be calculated using the perturbed matrix.
    AUC_key: str, optional
        In case calculate_perturbed_auc_values is set to True, key under which to find non-perturbed AUC values.
    perturbed_matrix: pd.DataFrame, optional
        Perturbed gene expression matrix, calculated using the simulate_perturbation function. 
        If set to None, this will be calculated.
    perturbation: dict, optional
        Dictionary specifying perturbation to simulate, has to be provided when perturbed_matrix is set to None.
        Example: {"SOX10": 0}.
    eRegulon_metadata_key: str, optional
        Key in scplus_obj.uns.keys() under which to find the eRegulon metadata.
    eRegulon_signatures_key: str, optional
        Key in scplus_obj.uns.keys() under which to find the eRegulon signatures.
    n_iter: int
        Number of itertions to simulate. Default is 5
    regressors: dict
        Dictionary of regressors as generated by train_gene_expression_models. 
        If set to None, this dictionary will be generated internally.
    genes: List
        List of genes for which to train the regression models. Default uses all genes.
    regressor_type: str
        Method to use for regression, options are GBM (Gradient Boosting Machine) and RF (Random Forrest).
    regressor_kwargs: dict
        Keyword arguments containing parameters to use for training the regression model.
    eRegulons_to_use: List
        List of eRegulons to consider as predictors. Default uses all eRegulons in scplus_obj.uns[eRegulon_metadata_key]
    grid_offset_frac: float
        Fraction of whitespace to use surounding the plot for plotting the arrows.
    grid_n_cols: int
        Number of columns to plot the grid of arrows
    grid_n_rows: int
        Number of rows to plot the grid of arrows
    grid_n_neighbors: int
        Number of neighbors to consider when calculating the grid of arrows.
    n_cpu: int
        Number of cpus to use.
    figsize: tuple
        Tuple indicating the size of the plot
    save: str
        Path where to save the figure.

    """

    level = logging.INFO
    format = '%(asctime)s %(name)-12s %(levelname)-8s %(message)s'
    handlers = [logging.StreamHandler(stream=sys.stdout)]
    logging.basicConfig(level=level, format=format, handlers=handlers)
    log = logging.getLogger('perturbation')
    if perturbed_matrix is None:
        if perturbation is None:
            raise ValueError("Please provide a perturbation, by setting the perturbation parameter to {<TF>: <new_expression_value>}")
        log.info(f'Caclulating perturbation matrix for: {perturbation} over {n_iter} iterations.')
        perturbed_matrix = simulate_perturbation(
            scplus_obj = scplus_obj,
            perturbation = perturbation, 
            eRegulon_metadata_key = eRegulon_metadata_key,
            n_iter = n_iter, 
            regressors = regressors, 
            genes = genes_to_use, 
            regressor_type = regressor_type,
            regressor_kwargs = regressor_kwargs, 
            eRegulons_to_use = eRegulons_to_use, 
            keep_intermediate = False)
    
    if calculate_perturbed_auc_values:
        log.info('Generating ranking based on perturbed matrix.')
        perturbed_ranking = _make_rankings(perturbed_matrix)
        log.info('Scoring eRegulons.')
        perturbed_matrix = score_eRegulons(
            scplus_obj = scplus_obj,
            ranking = perturbed_ranking,
            eRegulon_signatures_key = eRegulon_signatures_key,
            enrichment_type = 'gene',
            inplace = False,
            n_cpu = n_cpu)

    log.info(f'Projecting perturbation effect in embedding: {reduction_name}')
    delta_embedding = _project_perturbation_in_embedding(
        scplus_obj = scplus_obj, 
        original_matrix = scplus_obj.uns[AUC_key]['Gene_based'] if calculate_perturbed_auc_values else scplus_obj.to_df('EXP'), 
        perturbed_matrix = perturbed_matrix, 
        reduction_name = reduction_name, 
        sigma_corr = 0.05, 
        n_cpu = n_cpu)

    log.info('Calculating grid of arrows')
    embedding = scplus_obj.dr_cell[reduction_name].to_numpy()
    grid_xy, uv, mask = _calculate_grid_arrows(
        embedding=embedding, 
        delta_embedding=delta_embedding,
        offset_frac=grid_offset_frac,
        n_grid_cols=grid_n_cols,
        n_grid_rows=grid_n_rows,
        n_neighbors=grid_n_neighbors,
        n_cpu=n_cpu)
    distances = np.sqrt((uv**2).sum(1))
    norm = matplotlib.colors.Normalize(vmin=0.15, vmax=0.5, clip=True)
    scale = lambda X: [(x - min(X)) / (max(X) - min(X)) for x in X]
    uv[np.logical_or(~mask, np.array(scale(distances)) < 0.15)] = np.nan
    log.info('Plotting')
    fig, ax = plt.subplots(figsize=figsize)
    ax = plot_metadata_given_ax(
        scplus_obj=scplus_obj,
        reduction_name=reduction_name,
        ax = ax,
        variable = variable,
        show_label = False,
        show_legend = True,
        **kwargs)
    ax.streamplot(
            grid_xy.reshape(grid_n_cols,grid_n_rows, 2)[:, :, 0],
            grid_xy.reshape(grid_n_cols,grid_n_rows, 2)[:, :, 1],
            uv.reshape(grid_n_cols,grid_n_rows, 2)[:, :, 0],
            uv.reshape(grid_n_cols,grid_n_rows, 2)[:, :, 1], 
            density = density, 
            color = np.array(scale(distances)).reshape(grid_n_cols, grid_n_rows),
            cmap = 'Greys', 
            zorder = 10, 
            norm = norm,
            linewidth = arrow_width,
            arrowsize = arrowsize)
    ax.grid(False)
    if save is not None:
        fig.savefig(save,dpi=600)
    else:
        plt.show(fig)
        return ax

# %%
import scenicplus
import scenicplus.simulation
from scenicplus.simulation import _project_perturbation_in_embedding
from scenicplus.simulation import _calculate_grid_arrows
import seaborn as sns
import matplotlib
_ = plot_perturbation_effect_in_embedding_custom(
        scplus_obj = scplus_obj,
        reduction_name = 'eRegulons_PCA_gene_based',
        n_cpu = 5,
        perturbation = {'Fos': 0}, #specifies that we want to set the expression of Fos to 0 in all cells.
        variable = 'summarized_celltype',
        color_dictionary = {'summarized_celltype': mapping_color_dict},
        genes_to_use = hvg,
        figsize = (5, 5),
        density = 1,
        arrow_width = 4,
        arrowsize = 2,
        dot_size = 15,
        save = "E4AD_1yr/fos_ko.png")

# %%
_ = plot_perturbation_effect_in_embedding_custom(
        scplus_obj = scplus_obj,
        reduction_name = 'eRegulons_PCA_gene_based',
        n_cpu = 5,
        perturbation = {'Egr1': 0}, #specifies that we want to set the expression of Egr1 to 0 in all cells.
        variable = 'summarized_celltype',
        color_dictionary = {'summarized_celltype': mapping_color_dict},
        genes_to_use = hvg,
        figsize = (5, 5),
        density = 1.1,
        arrow_width = 3.5,
        arrowsize = 2.1,
        dot_size = 15,
        save = "E4AD_1yr/egr1_ko.png")

# %%
_ = plot_perturbation_effect_in_embedding_custom(
        scplus_obj = scplus_obj,
        reduction_name = 'eRegulons_PCA_gene_based',
        n_cpu = 5,
        perturbation = {'Sox5': 0}, #specifies that we want to set the expression of Sox5 to 0 in all cells.
        variable = 'summarized_celltype',
        color_dictionary = {'summarized_celltype': mapping_color_dict},
        genes_to_use = hvg,
        figsize = (5, 5),
        density = 1.1,
        arrow_width = 3.5,
        arrowsize = 2.1,
        dot_size = 15,
        save = "E4AD_1yr/sox5_ko.png")

# %%
_ = plot_perturbation_effect_in_embedding_custom(
        scplus_obj = scplus_obj,
        reduction_name = 'eRegulons_PCA_gene_based',
        n_cpu = 5,
        perturbation = {'Klf4': 0}, #specifies that we want to set the expression of Klf4 to 0 in all cells.
        variable = 'summarized_celltype',
        color_dictionary = {'summarized_celltype': mapping_color_dict},
        genes_to_use = hvg,
        figsize = (5, 5),
        density = 1.1,
        arrow_width = 3.5,
        arrowsize = 2.1,
        dot_size = 15,
        save = "E4AD_1yr/klf4_ko.png")

# %%
_ = plot_perturbation_effect_in_embedding_custom(
        scplus_obj = scplus_obj,
        reduction_name = 'eRegulons_PCA_gene_based',
        n_cpu = 5,
        perturbation = {'Nfkb2': 0}, #specifies that we want to set the expression of Nfkb2 to 0 in all cells.
        variable = 'summarized_celltype',
        color_dictionary = {'summarized_celltype': mapping_color_dict},
        genes_to_use = hvg,
        figsize = (5, 5),
        density = 1.1,
        arrow_width = 3.5,
        arrowsize = 2.1,
        dot_size = 15,
        save = "E4AD_1yr/nfkb2_ko.png")
